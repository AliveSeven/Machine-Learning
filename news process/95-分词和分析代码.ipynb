# %%
# 这里是逆向最大匹配分词算法
import re

print("--------------------对新闻进行逆向最大匹配分词，分词后的结果是↓--------------------")
ans_reverse=[]  #存放逆向匹配的结果，相当于栈，后面用于错误分析
max_length=4    #分词字典中最大长度字符串的长度
dic_list=[] #分词字典列表
NiXiang = [] # 存放分词结果，后面用于错误分析

with open('95字典.txt',encoding='UTF-8') as fp:  # 对字典进行切分，将里面的元素增加到一个列表里面
    for line in fp:
        line = re.sub(r'[\n]','',line) # 将line中的'\n'去掉
        if(line == ''):  # 去掉''
            continue
        dic_list.append(line)  # 加入分词列表

txtFiles = '95-预处理.txt'     # 待分词的文本（新闻）
with open(txtFiles, encoding='ANSI') as fp:  # 打开新闻，这里是我的新闻是ANSI，所以以ANSI的方式打开
        for line in fp:
            sentence = re.sub(r'[\n]','',line) #待分词的句子，去除\n
            #2、逆向最大匹配
            len_row=len(sentence)          #len_orw为当前为划分句子的长度
            while len_row>0 :              #当前待划分句子长度为0时，结束划分
                divide = sentence[-max_length:]   # 截取长度为max_length的字符串
                while divide not in dic_list:     # #当前截取的字符串不在分词字典中，则进循环
                    if len(divide)==1:            # #当前截取的字符串长度为1时，说明分词字典无匹配项
                        break                     # #直接保留当前的一个字
                    divide=divide[1:]   #注意这里缩短截取字符串是缩短前部分，保留后部分
                ans_reverse.append(divide)        #记录下当前截取的字符串
                sentence = sentence[0:len(sentence)-len(divide)]      #截取未分词的句子
                len_row = len(sentence)              #记录未分词的句子的长度
        for i in ans_reverse:  # 输出分词结果
            print(i)
            NiXiang.append(i) # 将分词去掉空格加到列表里面
# Out:
# --------------------对新闻进行逆向最大匹配分词，分词后的结果是↓--------------------
# 第一页
# ;
# ）
# rou
#
# lood
# （
# 血型
# 遗传性状
# 一种
# 的
# 出来
# 表现
# 形式
# 抗原
# 血液
# 以
# 差异
# 抗原
# 着
# 存在
# 也
# 之间
# 个体
# ，
# 蛋白
# 血浆
# 某些
# 乃至
# 血小板
# 、
# 白细胞
# 在
# ，
# 外
# 红细胞
# 除
# 知道
# 现已
# 但
# ；
# 差异
# 的
# 间
# 个体
# 在
# 抗原
# 红细胞
# 专指
# 血型
# ，
# 讲
# 地
# 狭义
# 差异
# 的
# 出现
# 间
# 个体
# 在
# 抗原
# 的
# 成分
# 各
# 血液
# 包括
# 应
# 血型
# 的
# 广义
# ，
# 因此
# 意义
# 实践
# 和
# 理论
# 的
# 重要
# 具有
# 因此
# ，
# 实用价值
# 的
# 广泛
# 有
# 都
# 学科
# 等
# 临床医学
# 、
# 法医学
# 、
# 遗传学
# 、
# 人类学
# 在
# 血型
# 系统
# 血型
# 的
# 发现
# 施泰纳
# 兰德
# ．
# K
# 奥地利
# 由
# 年
# 1900
# 是
# 血型
# 红细胞
# 发生
# 不
# 则
# 的
# 有
# ，
# 凝集反应
# 发生
# 之间
# 血液
# 的
# 有
# 发现
# ，
# 后
# 混合
# 交叉
# 血清
# 的
# 别人
# 与
# 分别
# 红细胞
# 的
# 人
# 每个
# 把
# 他
# 抗体
# 一种
# 中有
# 血清
# ，
# 抗原
# 一种
# 有
# 上
# 红细胞
# ，
# 者
# 凝集
# 凡是
# 认为
# 他
# 凝集反应
# 发生
# 便
# ，
# 关系
# 特异
# 的
# 对应
# 相
# 有
# 抗体
# 与
# 抗原
# 如
# 凝集
# 发生
# 便会
# ，
# 抗体
# A
# 中有
# 血清
# ，
# 抗原
# A
# 有
# 上
# 红细胞
# 如
# 凝集
# 发生
# 不
# 就
# ，
# 抗体
# 的
# 对应
# 之
# 与
# 缺乏
# 中
# 血清
# 或
# ，
# 抗原
# 一种
# 某
# 缺乏
# 红细胞
# 如果
# 血型
# ABO
# 的
# 人
# 了
# 发现
# 他
# 原理
# 这个
# 根据
# 抗体
# P
# 及
# 抗体
# N
# 、
# 抗体
# M
# 叫做
# 分别
# ，
# 抗体
# 免疫性
# 种
# 3
# 了
# 产生
# 中
# 血清
# 家兔
# 在
# ，
# 体内
# 家兔
# 到
# 注射
# 分别
# 红细胞
# 的
# 人
# 不同
# 把
# 又
# 他
# 后来
# 抗原
# 的
# 种新
# 3
# 上
# 红细胞
# 确定
# 可
# 又
# ，
# 抗体
# 种
# 3
# 这
# 用
# 系统
# 血型
# 的
# 另外
# 是
# ，
# 的
# 遗传
# 独立
# 是
# ，
# 无关
# 血型
# ABO
# 与
# 抗原
# 的
# 新
# 这些
# 系统
# 一个
# 不是
# 也
# P
# 与
# N
# 、
# M
# 而且
# 的
# 遗传
# 独立
# 是
# 因此
# ，
# 关系
# 连锁
# 不是
# ，
# 相距甚远
# 也
# 位点
# 基因
# 的
# 系统
# 两个
# ，
# 上
# 染色体
# 一个
# 在
# 即使
# ，
# 上
# 染色体
# 的
# 不同
# 在
# 基因
# 血型
# 的
# 系统
# 血型
# 不同
# 控制
# 发现
# 容易
# 不
# 但
# 抗体
# 中有
# 血清
# ，
# 现象
# 凝集
# 看不出
# 后
# 结合
# 细胞
# 抗原
# 的
# 相应
# 与
# ，
# 抗体
# 完全
# 不
# 是
# 抗体
# 血型
# 有些
# 发现
# 人
# 被
# 陆续
# 抗原
# 血型
# 许多
# ，
# 从此
# ，
# 抗体
# 完全
# 不
# 检查
# 可
# 就
# 试验
# 这种
# ，
# 中来
# 检查
# 血型
# 到
# 应用
# 试验
# 球蛋白
# 抗人
# 年
# 1945
# 系统
# 血型
# 若干
# 了
# 确定
# 便
# 上
# 红细胞
# 的
# 人
# 在
# 这样
# ，
# 关系
# 什么
# 是
# 血型
# 的
# 发现
# 已经
# 与
# 抗原
# 这一
# 确定
# 就要
# 后
# 抗原
# 新
# 一个
# 发现
# 每当
# 分析
# 遗传学
# 进行
# 无法
# 它们
# 对
# ，
# 太低
# 频率
# 的
# 分布
# 中
# 群体
# 在
# 其
# 因
# 或
# ，
# 太高
# 频率
# 的
# 出现
# 中
# 群体
# 在
# 其
# 因
# 或
# ，
# 抗原
# 一些
# 还有
# ，
# 此外
# 确定
# 进一步
# 有待
# 归属
# 的
# 它们
# 对于
# ，
# 抗原
# 频率
# 低
# 及
# 抗原
# 高频率
# 叫做
# 分别
# 抗原
# 这些
# 把
# 暂且
# ，
# 以前
# 关系
# 遗传
# 的
# 它们
# 弄清
# 没有
# 在
# 抗原
# 血型
# 红细胞
# 蛋白
# 收缩
# 及膜
# 蛋白
# 简单
# 、
# 糖蛋白
# ：
# 蛋白质
# 种
# 3
# 夹杂着
# 中
# 细胞膜
# 红
# 抗原
# Rh
# 如
# ，
# 内
# 细胞膜
# 在
# 镶嵌
# 有些
# ；
# 抗原
# ABH
# 如
# ，
# 树枝
# 的
# 上
# 地面
# 在
# 伸出
# 好像
# ，
# 表面
# 细胞
# 在
# 突出
# 有些
# 抗原
# 红细胞
# 决定簇
# 抗原
# 叫做
# ，
# 部分
# 的
# 反应
# 特异
# 发生
# 抗体
# 与
# 抗原
# 清楚
# 不
# 大部分
# 但
# ，
# 清楚
# 已经
# 的
# 有
# ，
# 组成
# 化学
# 的
# 决定簇
# 抗原
# 血型
# 物质
# 血型
# 叫做
# ，
# 抗原
# 可溶性
# 存在
# 液中
# 体
# 在
# 血型
# 有些
# 决定簇
# 特异性
# 便是
# 糖链
# 这些
# ，
# 侧链
# 的
# 糖
# 一些
# 着
# 连接
# 上
# 骨架
# 的
# 肽链
# 在
# 即
# ，
# 糖蛋白
# 是
# 物质
# 血型
# Lewi
# 及
# ABH
# 的
# 分离出来
# 人体
# 从
# 特异性
# 的
# 不同
# 显出
# 就
# ，
# 不同
# 位置
# 存在
# 由于
# 糖
# 一种
# 或同
# 种类
# 的
# 糖
# 个别
# 上
# 糖链
# 在
# 只是
# ，
# 相似
# 很
# 决定簇
# 特异性
# 的
# 物质
# 血型
# Lewi
# 及
# ABH
# 特异性
# 的
# 不同
# 出
# 显示
# 便
# ，
# 相同
# 不
# 糖
# 一个
# 有
# 上
# 糖链
# 在
# 只是
# ，
# 特异性
# 抗原
# 的
# B
# 与
# A
# 比如
# 半乳糖
# -
# D
# 一个
# 却是
# 末端
# 终
# 的
# 糖链
# 在
# 决定簇
# 抗原
# B
# 而
# ，
# 胺
# 半乳糖
# 乙酰
# -
# N
# 一个
# 是
# 末端
# 终
# 的
# 糖链
# 在
# 决定簇
# 抗原
# A
# 不同
# 骨架
# 的
# 连接
# 但
# ，
# 相同
# 结构
# 糖链
# 决定簇
# 抗原
# 的
# 液中
# 体
# 与
# 虽
# ，
# 决定簇
# 抗原
# ABH
# 的
# 上
# 红细胞
# 糖蛋白
# 不是
# 而
# 糖脂
# 是
# 抗原
# ABH
# 的
# 上
# 红细胞
# 所以
# ，
# 一起
# 在
# 结合
# 蛋白质
# 与
# 不是
# 而
# ，
# 一起
# 在
# 结合
# 脂肪酸
# 与
# 醇
# 氨
# 鞘
# 神经
# 通过
# 是
# 糖链
# 的
# 上
# 红细胞
# 物
# 合
# 化
# 水
# 碳
# 是
# 也
# 决定簇
# 抗原
# 的
# 血型
# I
# 及
# P
# ·
# MN
# 消失
# 行
# 即
# 活性
# Rh
# ，
# 后
# 处理
# 等物
# 蛋白酶
# 及
# 脲素
# 、
# 氢化物
# 经硫
# 红细胞
# 因为
# ，
# 蛋白质
# 是
# 可能
# 决定簇
# 的
# 抗原
# Rh
# 反应
# 发生
# 细胞
# 的
# 抗原
# 一个
# 只有
# 其中
# 与
# 不
# 而
# ，
# 反应
# 发生
# 细胞
# 的
# 抗原
# 一个
# 另外
# 及
# 抗原
# I
# 带有
# 与
# 只
# ，
# 等
# IP1
# 抗
# ，
# IB
# 抗
# ，
# IA
# 抗
# ，
# IH
# 如抗
# ，
# 抗体
# 血型
# 一些
# 有
# 特异性
# 两种
# 具有
# 上
# 分子
# 一个
# 在
# ，
# 抗原
# 复合
# 为
# 抗原
# 这些
# 说明
# 的
# 来
# 吸附
# 中
# 血浆
# 是从
# 抗原
# Lewi
# 的
# 上
# 红细胞
# ，
# 抗原
# 的
# 中
# 血浆
# 是
# 实际上
# 抗原
# 血型
# Lewi
# 中
# 血浆
# 在于
# 存
# 不
# 但
# ，
# 抗原
# 可溶性
# 有
# 虽
# 液中
# 分泌
# 在
# 抗原
# I
# 存在
# 不
# 却
# 液中
# 分泌
# ，
# 抗原
# 可溶性
# 存在
# 中
# 血浆
# 在
# 是
# 血型
# 有些
# 另外
# 抗原
# 的
# 红细胞
# 为
# 表现
# ，
# 上
# 红细胞
# 到
# 吸附
# 中
# 血浆
# 从
# 再
# ，
# 中
# 血浆
# 到
# 脱落
# 白细胞
# 从
# 可能
# ，
# 抗原
# 的
# 白细胞
# 是
# 实际
# 抗原
# B
# 有关
# ）
# C4
# （
# 成分
# 第四
# 补体
# 的
# 中
# 血浆
# 与
# 抗原
# 的
# 血型
# r
# e
# d
# o
# R
# 及
# 血型
# o
# d
# i
# h
# C
# ）
# FS
# （
# 的
# 有
# 都
# 成份
# 两种
# 快慢
# ；
# ）
# S
# （
# 的
# 泳动慢
# ；
# ）
# F
# （
# 的
# 快
# 泳动
# ：
# 类型
# 种
# 3
# 见到
# 可以
# ，
# C4
# 的
# 人
# 分析
# 方法
# 电泳
# 用
# 抗原
# r
# e
# d
# o
# R
# 有
# 上
# 红细胞
# ，
# 人
# 的
# 成份
# F
# 只有
# 中
# 血浆
# 抗原
# o
# d
# i
# h
# C
# 有
# 上
# 红细胞
# ，
# 人
# 的
# 成份
# S
# 只有
# 抗原
# 两种
# r
# e
# d
# o
# R
# 及
# o
# d
# i
# h
# C
# 具有
# 同时
# 也
# 上
# 红细胞
# ，
# 人
# 的
# 全有
# 成份
# 两种
# 疏松
# 的
# 有
# ，
# 密集
# 的
# 有
# ，
# 的
# 不同
# 是
# 分布
# 的
# 上
# 红细胞
# 在
# 抗原
# 血型
# 各种
# 强弱
# 的
# 抗原
# 了
# 决定
# 多少
# 的
# 数目
# 抗原
# 数目
# 抗原
# 的
# 上
# 红细胞
# 每个
# 推算出
# 可
# ，
# 强度
# 放射性
# 的
# 上
# 细胞
# 每个
# 根据
# ，
# 红细胞
# 的
# 人
# 检查
# ，
# 血清
# B
# 及抗
# A
# 兔抗
# 的
# 标记
# 碘
# 放射性
# 用
# 的
# 相同
# 不
# 是
# 强度
# 阶段
# 不同
# 个体发育
# 在
# 抗原
# 血型
# 各种
# 脆弱
# 细
# 成人
# 较
# 反应
# 之
# 抗体
# 的
# 相应
# 与其
# 抗原
# Lewi
# 及
# ABO
# 的
# 新生儿
# 弱
# 红细胞
# 成人
# 较
# 强度
# 反应
# 其
# 但
# ，
# 反应
# 发生
# 血清
# P1
# 抗
# 与
# 能
# 就
# 红细胞
# 之
# 胎儿
# 的
# 厘米
# 10
# 不到
# 弱
# 红细胞
# 成人
# 远较
# 强度
# 凝集反应
# 但
# ，
# 一样
# 红细胞
# 成人
# 与
# 几乎
# 能力
# 的
# I
# 抗
# 吸收
# 红细胞
# 的
# 新生儿
# 强
# 红细胞
# 成人
# 比
# 却
# 凝集
# 的
# 血清
# i
# 抗
# 与
# 可是
# 完全
# 发育
# 已
# 时
# 出生
# 在
# 抗原
# 的
# 系统
# 等
# Do
# 及
# Di
# 、
# MNS
# 、
# Jk
# 、
# y
# f
# f
# u
# D
# 、
# Kell
# 、
# Rh
# 而
# ，
# 弱
# 红细胞
# 成人
# 较
# 稍
# 上
# 红细胞
# 新生儿
# 在
# 抗原
# Xa
# 及
# Ya
# 发现
# 不能
# 上
# 红细胞
# 在
# 但
# ，
# 检出
# 可以
# 中
# 血浆
# 新生儿
# 在
# 抗原
# 的
# 血型
# o
# d
# i
# h
# C
# 抗体
# 抗体
# 血型
# 抗体
# 是
# 都
# 球蛋白
# 免疫
# 所有
# 一定
# 不
# 但
# ，
# 球蛋白
# 免疫
# 是
# 球蛋白
# 免疫
# 为
# 便
# 糖蛋白
# 的
# 结构
# 抗体
# 具有
# 只要
# IE
# 及
# ID
# 、
# IA
# 、
# IM
# 、
# IG
# 叫做
# 分别
# ，
# 球蛋白
# 免疫
# 五类
# 具有
# 人类
# 发现
# 现已
# ，
# 表示
# I
# 以
# 球蛋白
# 免疫
# 三类
# IA
# 及
# IM
# 、
# IG
# 即
# ，
# 三类
# 只有
# 球蛋白
# 免疫
# 的
# 有关
# 血型
# 与
# 之分
# ”
# 抗体
# 免疫性
# “
# 及
# ”
# 抗体
# 天然
# “
# 所谓
# 有
# ，
# 抗原刺激
# 的
# 查觉
# 可
# 有
# 是否
# 出现
# 体内
# 在
# 抗体
# 根据
# 抗体
# 免疫性
# 叫作
# ，
# 抗体
# 的
# 产生
# 所
# 中
# 血清
# 后
# 刺激
# 的
# 抗原
# 异种
# 或
# 同种
# 受
# 机体
# ；
# ”
# 抗体
# 天然
# “
# 叫做
# ，
# 抗体
# 的
# 出现
# 中
# 血清
# 的
# 体内
# 在
# 就
# 抗原刺激
# 未经
# 凡
# 抗体
# 反应
# 交叉
# 的
# 产生
# 所
# ，
# 后
# 物质
# 这些
# 接触
# 机体
# ，
# 物质
# 的
# 相似
# 抗原
# 血型
# 与
# 一些
# 着
# 存在
# 周围环境
# ，
# 凝集素
# 异种
# 是
# ”
# 抗体
# 天然
# “
# 认为
# 解释
# 一种
# 另
# ；
# 抗体
# 特异性
# 产生
# 能
# 就
# 抗原刺激
# 需要
# 不
# ，
# 细胞
# ”
# 致敏
# 抗原
# “
# 存在
# 体内
# 在
# 认为
# 说法
# 一种
# ：
# 解释
# 两种
# 有
# 产生
# 的
# ”
# 抗体
# 天然
# “
# 对于
# 抗体
# 反应
# 交叉
# 产生
# 便
# ，
# 后
# 细菌
# 这些
# 吞下
# 或
# 吸入
# 人们
# 当
# ，
# 抗原
# 的
# 相似
# 抗原
# B
# ，
# A
# 的
# 人
# 与
# 含有
# 细菌
# 某些
# 比如
# 第二页
# 活性
# 无
# 时即
# ℃
# 25
# 超过
# 温度
# 当
# ”
# 抗体
# 天然
# “
# 很多
# 有
# ，
# 强
# 反应
# 细胞
# 抗原
# 的
# 相应
# 与其
# 低温
# 在
# ”
# 抗体
# 天然
# “
# 没有
# 则
# 的
# 有
# ，
# 能力
# 的
# 补体
# 结合
# 有
# ”
# 抗体
# 天然
# “
# 的
# 有
# 能力
# 的
# 补体
# 结合
# 没有
# 就
# N
# 及抗
# M
# 而抗
# ，
# 能力
# 的
# 补体
# 结合
# 有
# 都
# 几乎
# 抗体
# 血型
# Lewi
# 如
# 球蛋白
# 免疫
# IG
# 却是
# ”
# 抗体
# 天然
# “
# 有些
# 但
# ，
# 球蛋白
# 免疫
# IM
# 是
# 通常
# ”
# 抗体
# 天然
# “
# IG
# 是
# ”
# 抗体
# 天然
# “
# K
# 及抗
# N
# 抗
# 、
# M
# 抗
# ，
# Lea
# 抗
# 的
# 如有
# 抗体
# 的
# 产生
# 而
# 状态
# 超免疫
# 处于
# 后
# 抗原刺激
# 异种
# 或
# 同种
# 受
# 机体
# 指
# 是
# 则
# 抗体
# 免疫性
# 原因
# 主要
# 的
# 免疫抗体
# 同种
# 产生
# 是
# 妊娠
# 、
# 输血
# 例子
# 的
# 抗体
# 免疫性
# 的
# 引起
# 免疫
# 异种
# 是
# ，
# 升高
# 效价
# B
# 抗
# 、
# A
# 抗
# 的
# 中
# 血清
# ，
# 人
# 的
# 浸液
# 肝
# 、
# 胃
# 的
# 过猪
# 使用
# 以及
# ，
# 注射
# ）
# 抗毒素
# 破伤风
# 、
# 白喉
# （
# 抗血清
# 、
# 菌苗
# 接受
# 不同
# ”
# 抗体
# 天然
# “
# 与
# 方面
# 许多
# 在
# ，
# B
# 及抗
# A
# 抗
# 免疫性
# 抗体
# 完全
# 不
# 称为
# 抗体
# 的
# 这样
# ，
# 凝集
# 出现
# 不能
# 但
# ，
# ）
# 致敏
# （
# 结合
# 细胞
# 抗原
# 的
# 相应
# 与其
# 只能
# 中
# 介质
# 盐水
# 在
# 抗体
# 的
# 有
# ；
# 抗体
# 完全
# 称为
# 抗体
# 的
# 这样
# ，
# 凝集
# 出现
# 即可
# 中
# 介质
# 盐水
# 在
# 细胞
# 抗原
# 的
# 相应
# 与其
# 抗体
# 的
# 有
# 帮助
# 的
# 血清
# 球蛋白
# 抗
# 利用
# 或
# ，
# 液中
# 胶体
# 大分子
# 在
# 悬浮
# 红细胞
# 将
# 或
# ，
# 红细胞
# 处理
# 如酶
# ，
# 介质
# 其他
# 借助
# 需
# 还
# ，
# 凝集
# 出现
# 细胞
# 抗原
# 的
# 相应
# 与其
# 抗体
# 完全
# 不
# 使
# 欲
# 抗体
# 的
# 类别
# IG
# 多为
# 抗体
# 完全
# 不
# 而
# ，
# 抗体
# 的
# 类型
# IM
# 指
# 是
# 一般
# 抗体
# 完全
# 实际上
# 位置
# 主要
# 占
# 不
# 中
# 抗体
# 血型
# 在
# ，
# 液中
# 分泌
# 在
# 主要
# IA
# 功能
# 和
# 结构
# 的
# 血型
# 等
# HLA
# 和
# MN
# 、
# ABO
# 血型
# 种
# 4
# 等
# O型
# 和
# AB
# 、
# B
# 、
# A
# 分为
# 可
# 血型
# ABO
# 抗体
# B
# 抗
# 和
# 抗体
# A
# 抗
# 含有
# 中
# 血清
# 人
# 的
# O型
# ，
# O型
# 叫做
# ，
# 抗原
# H
# 只有
# 红细胞
# ；
# 抗体
# B
# 抗
# 和
# 抗体
# A
# 抗
# 没有
# 中
# 血清
# 人
# 的
# 血型
# 这种
# ，
# AB型
# 叫做
# ，
# 抗原
# H
# 和
# 抗原
# B
# 、
# 抗原
# A
# 含
# 红细胞
# ；
# 抗体
# A
# 抗
# 含有
# 中
# 血清
# 人
# 的
# B型
# ，
# B型
# 叫做
# 的
# 抗原
# H
# 和
# 抗原
# B
# 含
# 红细胞
# ；
# 抗体
# B
# 抗
# 含有
# 中
# 血清
# 人
# 的
# A型
# ，
# A型
# 叫做
# 的
# 抗原
# H
# 和
# 抗原
# A
# 含
# 红细胞
# 液中
# 分泌
# 等
# 精液
# 、
# 胃液
# 、
# 唾液
# 于
# 出现
# 还
# ，
# 上外
# 细胞膜
# 红
# 在于
# 存
# 除
# 物质
# 血型
# ABO
# 物质
# 血型
# ABO
# 中有
# 唾液
# 汉族人
# ％
# 60
# 中国
# ）
# 上
# 糖链
# 在
# 决定簇
# 的
# 抗原
# 血型
# 即
# （
# 组成
# 的
# 糖链
# 抗原
# 血型
# 取决于
# 主要
# 特异性
# 的
# 血型
# 而
# ，
# 糖脂
# 或
# 糖蛋白
# 的
# 抗原
# 血型
# 构成
# 指
# 是
# 本质
# 化学
# 的
# 物质
# 血型
# 单糖
# 个
# 1
# 的
# 末端
# 糖链
# 在于
# 仅
# ，
# 差异
# 的
# 结构
# 化学
# 抗原
# 血型
# 种
# H3
# 、
# B
# 、
# A
# 半乳糖
# 乙酰
# -
# N
# 或
# 半乳糖
# 个
# 1
# 少
# 末端
# 糖链
# 则
# 相比
# 抗原
# B
# 、
# A
# 和
# 抗原
# H
# ，
# 半乳糖
# 为
# 末端
# 糖链
# 抗原
# B
# 而
# ，
# 半乳糖
# 乙酰
# -
# N
# 为
# 末端
# 糖链
# 抗原
# A
# 获得成功
# O型
# 转变成
# B型
# 使
# 从而
# ，
# 半乳糖
# 的
# 上
# 抗原
# B
# 切去
# ，
# 红细胞
# B型
# 于
# 作用
# ）
# 糖苷酶
# 半乳
# （
# 酶
# 咖啡豆
# 绿
# 人用
# 已有
# 年
# 1981
# 亚型
# 的
# 血型
# A
# 发现
# 年
# 1911
# 于
# 斯费尔德
# 希尔
# ．
# L
# 邓格恩及
# vo
# ．
# E
# 凝集反应
# 发生
# 红细胞
# A型
# 的
# 强
# 反应
# 与
# 能
# 抗体
# 一种
# 还有
# 中
# 血清
# 人
# A型
# 的
# 弱
# 反应
# 在
# ，
# 一
# 不
# 强度
# 的
# 凝集反应
# 发生
# 血清
# A
# 抗
# 与
# 红细胞
# 的
# 人
# A型
# 不同
# 看到
# 他们
# 亚型
# A2
# 及
# A1
# 即
# ；
# 亚型
# 存在
# 中
# A型
# 在
# 认为
# 据此
# 弱
# 反应
# 血清
# A
# 抗
# 与
# 红细胞
# 型
# A2
# 而
# ，
# 强
# 反应
# ）
# 人
# O型
# 或
# B
# 来自
# （
# 血清
# A
# 抗
# 与
# 红细胞
# 型
# .
# A1
# A1
# 抗
# 的
# 不规则
# 还有
# ，
# 外
# B
# 抗
# 的
# 存在
# 除
# ，
# 中
# 血清
# 的
# 人
# 型
# A2
# 部分
# 在
# 而且
# A1
# 及抗
# A
# 抗
# ：
# 抗体
# 两种
# 中有
# 血清
# 人
# B型
# 在
# 反应
# 发生
# 细胞
# A1
# 与
# 只
# A1
# 抗
# ；
# 反应
# 发生
# 细胞
# A2
# 及
# A1
# 与
# 能
# A
# 抗
# 抗原
# 两种
# A1
# 及
# A
# 有
# 上
# 红细胞
# 型
# A1
# 抗原
# A
# 只有
# 上
# 细胞
# A2
# 亚型
# 等
# A2B
# 及
# A1B
# 分为
# 可
# 也
# AB型
# 亚型
# 其他
# 一些
# 还有
# 此外
# A
# 糖蛋白
# 血型
# 的
# 上
# 细胞膜
# 即红
# ，
# 抗原
# MN
# 叫
# 抗原
# 血型
# 另一类
# 上
# 细胞膜
# 红
# 血型
# MN
# 二聚物
# 的
# 两者
# 是
# A
# 糖蛋白
# 血型
# ，
# 2
# －
# PAS
# 和
# 1
# －
# PAS
# 即
# ，
# 区带
# 两条
# 显示
# 上
# 谱
# 凝胶电泳
# SOS
# 在
# 它
# ）
# 2
# 图
# （
# 测定
# 已
# 结构
# 一级
# 其
# ，
# 组成
# 氨基酸
# 个
# 131
# 由
# A
# 糖蛋白
# 血型
# 已知
# 氨基酸
# 酸性
# 多
# 含较
# ，
# 内侧
# 膜
# 位于
# 肽链
# 端
# C
# ；
# 以上
# 一半
# 的
# 唾液酸
# 全部
# 上
# 细胞膜
# 占红
# 唾液酸
# 中
# 糖链
# ，
# 糖链
# 型
# 糖苷键
# -
# N
# 条
# 1
# 和
# 糖链
# 型
# 糖苷键
# -
# O
# 条
# 15
# 有
# 分布
# 上
# 肽链
# 这段
# 在
# ，
# 有关
# 活性
# 血型
# 与
# ，
# 外侧
# 膜
# 位于
# 肽链
# 端
# N
# ；
# 脂层
# 膜
# 横穿
# 可
# ，
# 肽链
# 水性
# 疏
# 为
# 氨基酸
# 号
# 92
# ～
# 73
# 第
# 中间
# ，
# 结构
# 式
# 三节
# 呈
# 肽链
# 的
# A
# 糖蛋白
# 血型
# 失去
# 完全
# 抗原性
# 则
# 唾液酸
# 一个
# 切去
# 再
# 如
# ，
# 抗原
# N
# 为
# 则
# ，
# ）
# 氨酸
# 神经
# 乙酰
# -
# N
# （
# 唾液酸
# 个
# 1
# 切去
# 抗原
# M
# 将
# 酶
# 氨酸
# 神经
# 用
# 如果
# ，
# 组成
# 部分
# 两
# 抗原
# N
# 和
# 抗原
# M
# 由
# 抗原
# MN
# 抗原性
# 失去
# 即
# 后
# 保护
# 乙酰基
# 用
# 氨基
# 将
# 若
# ，
# 有关
# 氨基
# 的
# 上
# 肽链
# 和
# 还
# 抗原性
# 的
# 抗原
# MN
# HLA
# —
# —
# 血型
# 白细胞
# 一类
# 的
# 重要
# 最
# 中
# 抗原
# 白细胞
# 人类
# 是
# HLA
# 的
# 发现
# 多塞
# ．
# J
# 科学家
# 法国
# 年
# 1958
# 是
# Mac
# 抗原
# 白细胞
# 第一个
# 人体
# ，
# 较晚
# 了解
# 的
# 抗原
# 白细胞
# 对
# 人们
# ，
# 相比
# 血型
# 红细胞
# 与
# 存在
# 也
# 上
# 表面
# 细胞
# 其他
# 在
# HLA
# 而且
# ，
# 系列
# 个
# DP7
# 和
# DQ
# 、
# DR
# 、
# D
# 、
# C
# 、
# B
# 、
# A
# 分为
# 抗原
# 这些
# ，
# 以上
# 种
# 144
# 有
# 抗原
# HLA
# 发现
# 已
# ，
# 缩写
# 英文
# 的
# 抗原
# 白细胞
# 人体
# 是
# HLA
# ）
# 3
# 图
# （
# 相似
# 极
# 球蛋白
# 免疫
# 与
# 分子结构
# 其
# ，
# ）
# ％
# 9
# 为
# 含糖
# （
# 糖蛋白
# 一种
# 是
# 抗原
# HLA
# 条糖链
# 2
# 连接
# 上
# 重链
# ，
# ）
# 重链
# 条
# 2
# 和
# 轻链
# 条
# 2
# 含
# （
# 组成
# 肽链
# 条
# 4
# 由
# 分子
# HLA
# 球蛋白
# 微
# -
# β
# 为
# 轻链
# ，
# 区段
# Fc
# 的
# IG
# 球蛋白
# 免疫
# 相当于
# 部分
# 的
# 膜
# 插入
# 其
# ，
# 中
# 双脂层
# 的
# 细胞膜
# 在
# 镶嵌
# 部分
# 分子
# HLA
# 密切相关
# 系统
# 防御
# 免疫
# 的
# 功能
# 保卫
# 有
# 与
# HLA
# 故
# ，
# 相似
# 的
# 上
# 分子结构
# 由于
# 控制
# 的
# 规律
# 遗传
# 受
# 都
# 一样
# 血型
# 红细胞
# 和
# HLA
# ，
# 此外
# 上
# 染色体
# 对
# 6
# 第
# 在
# 基因
# 的
# A型
# HL
# 决定
# 多
# 之
# 亿种
# 上
# 有
# 型
# 白细胞
# 各种
# 的
# 出来
# 表现
# 因此
# ，
# 型
# 白细胞
# 种
# 10
# ～
# 5
# 的
# 中
# 系列
# 个
# DR5
# 和
# D
# 、
# C
# 、
# B
# 、
# A
# 查出
# 同时
# 可以
# 人
# 一个
# 所以
# ，
# 染色体
# 一套
# 获得
# 父母
# 从
# 可
# 分别
# 人
# 每个
# 的
# 困难
# 很
# 是
# 两个
# 的
# 相同
# HLA
# 找出
# 人间
# 的
# 血缘关系
# 无
# 在
# 不同
# 完全
# 或
# 完全相同
# HLA
# 机会
# 4
# ／
# 1
# 有
# 总是
# 之间
# 姊妹
# 同胞兄弟
# 但
# 工具
# 的
# 有力
# 最
# 是
# 测定
# HLA
# ，
# 时
# 关系
# 亲缘
# 法医鉴定
# 因此
# 血型
# 的
# 动物
# 系统
# 血型
# 有
# 都
# 动物
# 许多
# 和
# 鸡
# 、
# 狗
# 已知
# 现在
# ，
# 血型
# 有
# 人才
# 只有
# 认为
# 人们
# 过去
# 血型
# 种
# 4
# 有
# 角鲨
# 的
# 海湾
# 缅因
# 美国
# 在
# 生长
# 组合
# 的
# 类型
# 或
# 类型
# 抗原
# 种
# 8
# 有
# 至少
# 大马哈鱼
# 而异
# 种群
# 的
# 地区
# 不同
# 随
# 通常
# 出现
# 的
# 类型
# 不同
# 这些
# 种
# 4
# 有
# 也
# 猪
# ，
# 种
# 3
# 牛有
# ，
# 种
# 4
# 马有
# ，
# 血型
# 有
# 也
# 家畜
# 测定
# 来
# 血清
# B
# 抗
# 和
# A
# 抗
# 通过
# 可以
# 血型
# 的
# 灵长类
# AB型
# 及
# B型
# 、
# A型
# 有
# 血型
# 长臂猿
# ，
# A型
# 有
# 也
# B型
# 有
# 大猩猩
# ，
# B型
# 属于
# 猩猩
# ，
# A型
# 或
# O型
# 属于
# 全部
# 血
# 的
# 黑猩猩
# 抗原
# ABO
# 分泌
# 里
# 唾液
# 的
# 它们
# 在
# 但
# ，
# 抗原
# 没有
# 里
# 红血球
# 在
# 灵长类
# 低等
# 抗原
# 的
# 一样
# B
# 有象
# 里
# 唾液
# 在
# 的
# 个别
# 但
# ，
# A型
# 是
# 也
# 血型
# 猴
# 新大陆
# ，
# A型
# 血型
# 是
# 大多数
# 猴
# 旧大陆
# 的
# 抗原
# Rh
# 具
# 发现
# 也
# 中
# 灵长类
# 在
# ，
# 血型
# N
# 和
# 血型
# M
# 具有
# 了
# 发现
# 体内
# 黑猩猩
# 在
# 如
# ，
# 抗原
# 的
# M
# 人类
# 类似
# 具有
# 发现
# 中
# 灵长类
# 某些
# 在
# ;
# 2
# 资源网
# 高中生物
# :
# 来源

# %%
# 这里是HanLP分词
import re
from pyhanlp import * # 导入要分词用的pyhanlp库

HanList = [] # 创建一个列表保存HanLP分词结果
print("--------------------对新闻进行HanLP分词，分词后的结果是↓--------------------")
print('单词↓↓ 词性↓↓')
txtFiles = '95-预处理.txt'         # 要分词的文本（新闻）
with open(txtFiles, encoding='ANSI') as fp: 
        for line in fp: 
            line = re.sub(r'[\n]','',line) # 将line中的'\n'去掉
            # 进行HanLP中文分词
            for term in HanLP.segment(line):
                # 输出分词的单词，词性
                print("%s     %s" % (term.word, term.nature))
                HanList.append(term.word)  # 将HanLP分词结果保存在一个列表里面，后面做错误分析有用
# Out:
# --------------------对新闻进行HanLP分词，分词后的结果是↓--------------------
# 单词↓↓ 词性↓↓
# ;     w
# 第一页     nz
# 血型     n
# （     w
# lood     nx
#       w
# rou     nx
# ）     w
# 以     p
# 血液     n
# 抗原     n
# 形式     n
# 表现     v
# 出来     vf
# 的     ude1
# 一     m
# 种     q
# 遗传性状     gb
# 狭义     b
# 地     ude2
# 讲     v
# ，     w
# 血型     n
# 专指     n
# 红细胞     n
# 抗原     n
# 在     p
# 个体     n
# 间     f
# 的     ude1
# 差异     n
# ；     w
# 但     c
# 现已     v
# 知道     v
# 除     p
# 红细胞     n
# 外     f
# ，     w
# 在     p
# 白细胞     n
# 、     w
# 血小板     n
# 乃至     c
# 某些     rz
# 血浆     n
# 蛋白     n
# ，     w
# 个体     n
# 之间     f
# 也     d
# 存在     v
# 着     uzhe
# 抗原     n
# 差异     n
# 因此     c
# ，     w
# 广义     n
# 的     ude1
# 血型     n
# 应     v
# 包括     v
# 血液     n
# 各     rz
# 成分     n
# 的     ude1
# 抗原     n
# 在     p
# 个体     n
# 间     f
# 出现     v
# 的     ude1
# 差异     n
# 血型     n
# 在     p
# 人类学     n
# 、     w
# 遗传学     n
# 、     w
# 法医学     n
# 、     w
# 临床医学     nz
# 等     udeng
# 学科     n
# 都     d
# 有     vyou
# 广泛     a
# 的     ude1
# 实用价值     l
# ，     w
# 因此     c
# 具有     v
# 重要     a
# 的     ude1
# 理论     n
# 和     cc
# 实践     vn
# 意义     n
# 血型     n
# 系统     n
# 红细胞     n
# 血型     n
# 是     vshi
# 1900     m
# 年     qt
# 由     p
# 奥地利     nsf
# K     nx
# ．     w
# 兰德施泰纳     nrf
# 发现     v
# 的     ude1
# 他     rr
# 把     pba
# 每个     mq
# 人     n
# 的     ude1
# 红细胞     n
# 分别     d
# 与     cc
# 别人     rr
# 的     ude1
# 血清     n
# 交叉     vn
# 混合     vn
# 后     f
# ，     w
# 发现     v
# 有     vyou
# 的     ude1
# 血液     n
# 之间     f
# 发生     v
# 凝集反应     nz
# ，     w
# 有的     rz
# 则     d
# 不     d
# 发生     v
# 他     rr
# 认为     v
# 凡是     d
# 凝集     v
# 者     k
# ，     w
# 红细胞     n
# 上     f
# 有     vyou
# 一     m
# 种     q
# 抗原     n
# ，     w
# 血清     n
# 中     f
# 有     vyou
# 一     m
# 种     q
# 抗体     n
# 如     v
# 抗原     n
# 与     cc
# 抗体     n
# 有     vyou
# 相     d
# 对应     vi
# 的     ude1
# 特异     z
# 关系     n
# ，     w
# 便     d
# 发生     v
# 凝集反应     nz
# 如     v
# 红细胞     n
# 上     f
# 有     vyou
# A     nx
# 抗原     n
# ，     w
# 血清     n
# 中     f
# 有     vyou
# A     nx
# 抗体     n
# ，     w
# 便     d
# 会     v
# 发生     v
# 凝集     v
# 如果     c
# 红细胞     n
# 缺乏     v
# 某     rz
# 一     m
# 种     q
# 抗原     n
# ，     w
# 或     c
# 血清     n
# 中     f
# 缺乏     v
# 与     cc
# 之     uzhi
# 对应     vi
# 的     ude1
# 抗体     n
# ，     w
# 就     d
# 不     d
# 发生     v
# 凝集     v
# 根据     p
# 这个     rz
# 原理     n
# 他     rr
# 发现     v
# 了     ule
# 人     n
# 的     ude1
# ABO     nx
# 血型     n
# 后来     t
# 他     rr
# 又     d
# 把     pba
# 不同     a
# 人     n
# 的     ude1
# 红细胞     n
# 分别     d
# 注射     v
# 到     v
# 家兔     n
# 体内     s
# ，     w
# 在     p
# 家兔     n
# 血清     n
# 中     f
# 产生     v
# 了     ule
# 3     m
# 种     q
# 免疫性     n
# 抗体     n
# ，     w
# 分别     d
# 叫做     v
# M     nx
# 抗体     n
# 、     w
# N     nx
# 抗体     n
# 及     cc
# P     nx
# 抗体     n
# 用     p
# 这     rzv
# 3     m
# 种     q
# 抗体     n
# ，     w
# 又     d
# 可     v
# 确定     v
# 红细胞     n
# 上     f
# 3     m
# 种     q
# 新的     a
# 抗原     n
# 这些     rz
# 新的     a
# 抗原     n
# 与     cc
# ABO     nx
# 血型     n
# 无关     v
# ，     w
# 是     vshi
# 独立     a
# 遗传     vn
# 的     ude1
# ，     w
# 是     vshi
# 另外     c
# 的     ude1
# 血型     n
# 系统     n
# 而且     c
# M     nx
# 、     w
# N     nx
# 与     cc
# P     nx
# 也     d
# 不是     c
# 一个     mq
# 系统     n
# 控制     vn
# 不同     a
# 血型     n
# 系统     n
# 的     ude1
# 血型     n
# 基因     n
# 在     p
# 不同     a
# 的     ude1
# 染色体     n
# 上     f
# ，     w
# 即使     c
# 在     p
# 一个     mq
# 染色体     n
# 上     f
# ，     w
# 两     m
# 个     q
# 系统     n
# 的     ude1
# 基因     n
# 位点     n
# 也     d
# 相距甚远     l
# ，     w
# 不是     c
# 连锁     vn
# 关系     n
# ，     w
# 因此     c
# 是     vshi
# 独立     a
# 遗传     vn
# 的     ude1
# 有些     rz
# 血型     n
# 抗体     n
# 是     vshi
# 不     d
# 完全     ad
# 抗体     n
# ，     w
# 与     cc
# 相应     vi
# 的     ude1
# 抗原     n
# 细胞     n
# 结合     v
# 后     f
# 看不出     v
# 凝集     v
# 现象     n
# ，     w
# 血清     n
# 中     f
# 有     vyou
# 抗体     n
# 但     c
# 不     d
# 容易     ad
# 发现     v
# 1945     m
# 年     qt
# 抗     v
# 人     n
# 球蛋白     n
# 试验     vn
# 应用     vn
# 到     v
# 血型     n
# 检查     vn
# 中     f
# 来     vf
# ，     w
# 这种     r
# 试验     vn
# 就     d
# 可     v
# 检查     vn
# 不     d
# 完全     ad
# 抗体     n
# ，     w
# 从此     d
# ，     w
# 许多     m
# 血型     n
# 抗原     n
# 陆续     d
# 被     pbei
# 人     n
# 发现     v
# 每当     d
# 发现     v
# 一个     mq
# 新     a
# 抗原     n
# 后     f
# 就要     d
# 确定     v
# 这     rzv
# 一     m
# 抗原     n
# 与     cc
# 已经     d
# 发现     v
# 的     ude1
# 血型     n
# 是     vshi
# 什么     ry
# 关系     n
# ，     w
# 这样     rzv
# 在     p
# 人     n
# 的     ude1
# 红细胞     n
# 上     f
# 便     d
# 确定     v
# 了     ule
# 若干     m
# 血型     n
# 系统     n
# 此外     c
# ，     w
# 还有     v
# 一些     m
# 抗原     n
# ，     w
# 或     c
# 因其     c
# 在     p
# 群体     n
# 中     f
# 出现     v
# 的     ude1
# 频率     n
# 太高     d
# ，     w
# 或     c
# 因其     c
# 在     p
# 群体     n
# 中     f
# 分布     vi
# 的     ude1
# 频率     n
# 太低     nz
# ，     w
# 对     p
# 它们     rr
# 无法     v
# 进行     vn
# 遗传学     n
# 分析     vn
# 在     p
# 没有     v
# 弄清     v
# 它们     rr
# 的     ude1
# 遗传     vn
# 关系     n
# 以前     f
# ，     w
# 暂且     d
# 把     pba
# 这些     rz
# 抗原     n
# 分别     d
# 叫做     v
# 高频率     nz
# 抗原     n
# 及     cc
# 低     a
# 频率     n
# 抗原     n
# ，     w
# 对于     p
# 它们     rr
# 的     ude1
# 归属     vn
# 有待     v
# 进一步     d
# 确定     v
# 红细胞     n
# 血型     n
# 抗原     n
# 红细胞     n
# 膜     n
# 中     f
# 夹杂着     v
# 3     m
# 种     q
# 蛋白质     n
# ：     w
# 糖蛋白     gb
# 、     w
# 简单     a
# 蛋白     n
# 及     cc
# 膜     n
# 收缩     v
# 蛋白     n
# 红细胞     n
# 抗原     n
# 有些     rz
# 突出     a
# 在     p
# 细胞     n
# 表面     n
# ，     w
# 好像     v
# 伸出     v
# 在     p
# 地面     n
# 上     f
# 的     ude1
# 树枝     n
# ，     w
# 如     v
# ABH     nx
# 抗原     n
# ；     w
# 有些     rz
# 镶嵌     v
# 在     p
# 细胞膜     n
# 内     f
# ，     w
# 如     v
# Rh     nx
# 抗原     n
# 抗原     n
# 与     cc
# 抗体     n
# 发生     v
# 特异     z
# 反应     vn
# 的     ude1
# 部分     n
# ，     w
# 叫做     v
# 抗原     n
# 决定簇     gb
# 血型     n
# 抗原     n
# 决定簇     gb
# 的     ude1
# 化学     n
# 组成     v
# ，     w
# 有的     rz
# 已经     d
# 清楚     a
# ，     w
# 但     c
# 大部分     n
# 不     d
# 清楚     a
# 有些     rz
# 血型     n
# 在     p
# 体液     n
# 中     f
# 存在     v
# 可溶性     n
# 抗原     n
# ，     w
# 叫做     v
# 血型     n
# 物质     n
# 从     p
# 人体     n
# 分离出来     i
# 的     ude1
# ABH     nx
# 及     cc
# Lewi     nx
# 血型     n
# 物质     n
# 是     vshi
# 糖蛋白     gb
# ，     w
# 即     v
# 在     p
# 肽链     gb
# 的     ude1
# 骨架     n
# 上     f
# 连接     v
# 着     uzhe
# 一些     m
# 糖     n
# 的     ude1
# 侧     ng
# 链     ng
# ，     w
# 这些     rz
# 糖     n
# 链     ng
# 便是     v
# 特异性     gb
# 决定簇     gb
# ABH     nx
# 及     cc
# Lewi     nx
# 血型     n
# 物质     n
# 的     ude1
# 特异性     gb
# 决定簇     gb
# 很     d
# 相似     a
# ，     w
# 只是     d
# 在     p
# 糖     n
# 链     ng
# 上     f
# 个别     a
# 糖     n
# 的     ude1
# 种类     n
# 或     c
# 同一     b
# 种     q
# 糖     n
# 由于     p
# 存在     v
# 位置     n
# 不同     a
# ，     w
# 就     d
# 显出     v
# 不同     a
# 的     ude1
# 特异性     gb
# 比如     v
# A     nx
# 与     cc
# B     nx
# 的     ude1
# 抗原     n
# 特异性     gb
# ，     w
# 只是     d
# 在     p
# 糖     n
# 链     ng
# 上     f
# 有     vyou
# 一个     mq
# 糖     n
# 不     d
# 相同     a
# ，     w
# 便     d
# 显示     v
# 出     vf
# 不同     a
# 的     ude1
# 特异性     gb
# A     nx
# 抗原     n
# 决定簇     gb
# 在     p
# 糖     n
# 链     ng
# 的     ude1
# 终     d
# 末端     n
# 是     vshi
# 一个     mq
# N-     nx
# 乙酰     gb
# 半乳糖     nmc
# 胺     n
# ，     w
# 而     cc
# B     nx
# 抗原     n
# 决定簇     gb
# 在     p
# 糖     n
# 链     ng
# 的     ude1
# 终末     n
# 端     v
# 却是     d
# 一个     mq
# D-     nx
# 半     mq
# 乳糖     n
# 红细胞     n
# 上     f
# 的     ude1
# ABH     nx
# 抗原     n
# 决定簇     gb
# ，     w
# 虽     c
# 与     cc
# 体液     n
# 中的     v
# 抗原     n
# 决定簇     gb
# 糖     n
# 链     ng
# 结构     n
# 相同     a
# ，     w
# 但     c
# 连接     v
# 的     ude1
# 骨架     n
# 不同     a
# 红细胞     n
# 上     f
# 的     ude1
# 糖     n
# 链     ng
# 是     vshi
# 通过     p
# 神经     n
# 鞘     n
# 氨     n
# 醇     ag
# 与     cc
# 脂肪酸     n
# 结合     v
# 在     p
# 一起     s
# ，     w
# 而     cc
# 不是     c
# 与     cc
# 蛋白质     n
# 结合     v
# 在     p
# 一起     s
# ，     w
# 所以     c
# 红细胞     n
# 上     f
# 的     ude1
# ABH     nx
# 抗原     n
# 是     vshi
# 糖脂     gb
# 而     cc
# 不是     c
# 糖蛋白     gb
# MN     nx
# ·     w
# P     nx
# 及     cc
# I     nx
# 血型     n
# 的     ude1
# 抗原     n
# 决定簇     gb
# 也     d
# 是     vshi
# 碳水化合物     gc
# Rh     nx
# 抗原     n
# 的     ude1
# 决定簇     gb
# 可能     v
# 是     vshi
# 蛋白质     n
# ，     w
# 因为     c
# 红细胞     n
# 经     p
# 硫     n
# 氢化物     n
# 、     w
# 脲     g
# 素     ag
# 及     cc
# 蛋白酶     nmc
# 等     udeng
# 物     ng
# 处理     vn
# 后     f
# ，     w
# Rh     nx
# 活性     b
# 即行     v
# 消失     vi
# 有     vyou
# 一些     m
# 血型     n
# 抗体     n
# ，     w
# 如     v
# 抗     v
# IH     nx
# ，     w
# 抗     v
# IA     nx
# ，     w
# 抗     v
# IB     nx
# ，     w
# 抗     v
# IP     nx
# 1     m
# 等     udeng
# ，     w
# 只     d
# 与     cc
# 带有     v
# I     nx
# 抗原     n
# 及     cc
# 另外     c
# 一个     mq
# 抗原     n
# 的     ude1
# 细胞     n
# 发生     v
# 反应     vn
# ，     w
# 而     cc
# 不     d
# 与     cc
# 其中     rz
# 只有     c
# 一个     mq
# 抗原     n
# 的     ude1
# 细胞     n
# 发生     v
# 反应     vn
# 说明     v
# 这些     rz
# 抗原     n
# 为     p
# 复合     vn
# 抗原     n
# ，     w
# 在     p
# 一个     mq
# 分子     n
# 上     f
# 具有     v
# 两     m
# 种     q
# 特异性     gb
# Lewi     nx
# 血型     n
# 抗原     n
# 实际上     d
# 是     vshi
# 血浆     n
# 中的     v
# 抗原     n
# ，     w
# 红细胞     n
# 上     f
# 的     ude1
# Lewi     nx
# 抗原     n
# 是从     v
# 血浆     n
# 中     f
# 吸附     vn
# 来     vf
# 的     ude1
# I     nx
# 抗原     n
# 在     p
# 分泌液     nz
# 中     f
# 虽有     c
# 可溶性     n
# 抗原     n
# ，     w
# 但     c
# 不     d
# 存在     v
# 于     p
# 血浆     n
# 中     f
# 另外     c
# 有些     rz
# 血型     n
# 是     vshi
# 在     p
# 血浆     n
# 中     f
# 存在     v
# 可溶性     n
# 抗原     n
# ，     w
# 分泌液     nz
# 中     f
# 却     d
# 不     d
# 存在     v
# B     nx
# 抗原     n
# 实际     n
# 是     vshi
# 白细胞     n
# 的     ude1
# 抗原     n
# ，     w
# 可能     v
# 从     p
# 白细胞     n
# 脱落     v
# 到     v
# 血浆     n
# 中     f
# ，     w
# 再     d
# 从     p
# 血浆     n
# 中     f
# 吸附     vn
# 到     v
# 红细胞     n
# 上     f
# ，     w
# 表现     v
# 为     p
# 红细胞     n
# 的     ude1
# 抗原     n
# Chido     nx
# 血型     n
# 及     cc
# Roder     nx
# 血型     n
# 的     ude1
# 抗原     n
# 与     cc
# 血浆     n
# 中的     v
# 补体     gb
# 第     mq
# 四     m
# 成分     n
# （     w
# C     nx
# 4     m
# ）     w
# 有关     vn
# 用     p
# 电泳     n
# 方法     n
# 分析     vn
# 人     n
# 的     ude1
# C     nx
# 4     m
# ，     w
# 可以     v
# 见到     v
# 3     m
# 种     q
# 类型     n
# ：     w
# 泳     vg
# 动     v
# 快     a
# 的     ude1
# （     w
# F     nx
# ）     w
# ；     w
# 泳     vg
# 动     v
# 慢     a
# 的     ude1
# （     w
# S     nx
# ）     w
# ；     w
# 快慢     n
# 两     m
# 种     q
# 成份     n
# 都     d
# 有的     rz
# （     w
# FS     nx
# ）     w
# 血浆     n
# 中     f
# 只有     c
# F     nx
# 成份     n
# 的     ude1
# 人     n
# ，     w
# 红细胞     n
# 上     f
# 有     vyou
# Roder     nx
# 抗原     n
# 只有     c
# S     nx
# 成份     n
# 的     ude1
# 人     n
# ，     w
# 红细胞     n
# 上     f
# 有     vyou
# Chido     nx
# 抗原     n
# 两     m
# 种     q
# 成份     n
# 全     a
# 有的     rz
# 人     n
# ，     w
# 红细胞     n
# 上     f
# 也     d
# 同时     c
# 具有     v
# Chido     nx
# 及     cc
# Roder     nx
# 两     m
# 种     q
# 抗原     n
# 各种     rz
# 血型     n
# 抗原     n
# 在     p
# 红细胞     n
# 上     f
# 的     ude1
# 分布     vi
# 是     vshi
# 不同     a
# 的     ude1
# ，     w
# 有的     rz
# 密集     a
# ，     w
# 有的     rz
# 疏松     vn
# 抗原     n
# 数目     n
# 的     ude1
# 多少     ry
# 决定     v
# 了     ule
# 抗原     n
# 的     ude1
# 强弱     n
# 用     p
# 放射性     n
# 碘     n
# 标记     n
# 的     ude1
# 兔     ng
# 抗     v
# A     nx
# 及     cc
# 抗     v
# B     nx
# 血清     n
# ，     w
# 检查     vn
# 人     n
# 的     ude1
# 红细胞     n
# ，     w
# 根据     p
# 每个     mq
# 细胞     n
# 上     f
# 的     ude1
# 放射性     n
# 强度     n
# ，     w
# 可     v
# 推算出     v
# 每个     mq
# 红细胞     n
# 上     f
# 的     ude1
# 抗原     n
# 数目     n
# 各种     rz
# 血型     n
# 抗原     n
# 在     p
# 个体发育     gb
# 不同     a
# 阶段     n
# 强度     n
# 是     vshi
# 不     d
# 相同     a
# 的     ude1
# 新生儿     n
# 的     ude1
# ABO     nx
# 及     cc
# Lewi     nx
# 抗原     n
# 与其     c
# 相应     vi
# 的     ude1
# 抗体     n
# 之     uzhi
# 反应     vn
# 较     d
# 成人细     nr
# 脆弱     a
# 不到     v
# 10     m
# 厘米     q
# 的     ude1
# 胎儿     n
# 之     uzhi
# 红细胞     n
# 就     d
# 能     v
# 与     cc
# 抗     v
# P     nx
# 1     m
# 血清     n
# 发生     v
# 反应     vn
# ，     w
# 但     c
# 其     rz
# 反应     vn
# 强度     n
# 较     d
# 成人     n
# 红细胞     n
# 弱     a
# 新生儿     n
# 的     ude1
# 红细胞     n
# 吸收     v
# 抗     v
# I     nx
# 的     ude1
# 能力     n
# 几乎     d
# 与     cc
# 成人     n
# 红细胞     n
# 一样     uyy
# ，     w
# 但     c
# 凝集反应     nz
# 强度     n
# 远     a
# 较     d
# 成人     n
# 红细胞     n
# 弱     a
# 可是     c
# 与     cc
# 抗     v
# i     nx
# 血清     n
# 的     ude1
# 凝集     v
# 却     d
# 比     p
# 成人     n
# 红细胞     n
# 强     a
# Ya     nx
# 及     cc
# Xa     nx
# 抗原     n
# 在     p
# 新生儿     n
# 红细胞     n
# 上     f
# 稍     d
# 较     d
# 成人     n
# 红细胞     n
# 弱     a
# ，     w
# 而     cc
# Rh     nx
# 、     w
# Kell     nx
# 、     w
# Duffy     nx
# 、     w
# Jk     nx
# 、     w
# MNS     nx
# 、     w
# Di     nx
# 及     cc
# Do     nx
# 等     udeng
# 系统     n
# 的     ude1
# 抗原     n
# 在     p
# 出生     vi
# 时     qt
# 已     d
# 发育     vi
# 完全     ad
# Chido     nx
# 血型     n
# 的     ude1
# 抗原     n
# 在     p
# 新生儿     n
# 血浆     n
# 中     f
# 可以     v
# 检出     nz
# ，     w
# 但     c
# 在     p
# 红细胞     n
# 上     f
# 不能     v
# 发现     v
# 血型     n
# 抗体     n
# 抗体     n
# 是     vshi
# 免疫     vn
# 球蛋白     n
# ，     w
# 但     c
# 不一定     nz
# 所有     b
# 免疫球蛋白     gb
# 都     d
# 是     vshi
# 抗体     n
# 只要     c
# 具有     v
# 抗     v
# 体     ng
# 结构     n
# 的     ude1
# 糖蛋白     gb
# 便     d
# 为     p
# 免疫球蛋白     gb
# 免疫球蛋白     gb
# 以     p
# I     nx
# 表示     v
# ，     w
# 现已     v
# 发现     v
# 人类     n
# 具有     v
# 五     m
# 类     q
# 免疫球蛋白     gb
# ，     w
# 分别     d
# 叫做     v
# IG     nx
# 、     w
# IM     nx
# 、     w
# IA     nx
# 、     w
# ID     nx
# 及     cc
# IE     nx
# 与     cc
# 血型     n
# 有     vyou
# 关的     nr
# 免疫球蛋白     gb
# 只有     c
# 三类     b
# ，     w
# 即     v
# IG     nx
# 、     w
# IM     nx
# 及     cc
# IA     nx
# 三     m
# 类     q
# 根据     p
# 抗体     n
# 在     p
# 体内     s
# 出现     v
# 是否     v
# 有     vyou
# 可     v
# 查觉     nrf
# 的     ude1
# 抗原刺激     gb
# ，     w
# 有     vyou
# 所谓     v
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 及     cc
# “     w
# 免疫性     n
# 抗体     n
# ”     w
# 之     uzhi
# 分     qt
# 凡     d
# 未经     d
# 抗原刺激     gb
# 就     d
# 在     p
# 体内     s
# 的     ude1
# 血清     n
# 中     f
# 出现     v
# 的     ude1
# 抗体     n
# ，     w
# 叫做     v
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# ；     w
# 机体     n
# 受     v
# 同种     r
# 或     c
# 异种     nz
# 抗原     n
# 的     ude1
# 刺激     v
# 后     f
# 血清     n
# 中所     j
# 产生     v
# 的     ude1
# 抗体     n
# ，     w
# 叫作     v
# 免疫性     n
# 抗体     n
# 对于     p
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 的     ude1
# 产生     v
# 有     vyou
# 两     m
# 种     q
# 解释     v
# ：     w
# 一     m
# 种     q
# 说法     n
# 认为     v
# 在     p
# 体内     s
# 存在     v
# “     w
# 抗原     n
# 致敏     gb
# ”     w
# 细胞     n
# ，     w
# 不     d
# 需要     v
# 抗原刺激     gb
# 就     d
# 能     v
# 产生     v
# 特异性     gb
# 抗体     n
# ；     w
# 另     rz
# 一     m
# 种     q
# 解释     v
# 认为     v
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 是     vshi
# 异种     nz
# 凝集素     gc
# ，     w
# 周围环境     nz
# 存在     v
# 着     uzhe
# 一些     m
# 与     cc
# 血型     n
# 抗原     n
# 相似     a
# 的     ude1
# 物质     n
# ，     w
# 机体     n
# 接触     v
# 这些     rz
# 物质     n
# 后     f
# ，     w
# 所     usuo
# 产生     v
# 的     ude1
# 交叉     vn
# 反应     vn
# 抗体     n
# 比如     v
# 某些     rz
# 细菌     n
# 含有     v
# 与     cc
# 人     n
# 的     ude1
# A     nx
# ，     w
# B     nx
# 抗原     n
# 相似     a
# 的     ude1
# 抗原     n
# ，     w
# 当     p
# 人们     n
# 吸入     v
# 或     c
# 吞下     vf
# 这些     rz
# 细菌     n
# 后     f
# ，     w
# 便     d
# 产生     v
# 交叉     vn
# 反应     vn
# 抗体     n
# 第二     mq
# 页     q
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 在     p
# 低温     n
# 与     cc
# 其     rz
# 相应     vi
# 的     ude1
# 抗原     n
# 细胞     n
# 反应     vn
# 强     a
# ，     w
# 有     vyou
# 很     d
# 多     a
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 当     p
# 温度     n
# 超过     v
# 25     m
# ℃     q
# 时     qt
# 即     v
# 无     v
# 活性     b
# 有的     rz
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 有     vyou
# 结合     v
# 补体     gb
# 的     ude1
# 能力     n
# ，     w
# 有的     rz
# 则     d
# 没有     v
# 如     v
# Lewi     nx
# 血型     n
# 抗体     n
# 几乎     d
# 都     d
# 有     vyou
# 结合     v
# 补体     gb
# 的     ude1
# 能力     n
# ，     w
# 而     cc
# 抗     v
# M     nx
# 及     cc
# 抗     v
# N     nx
# 就     d
# 没有     v
# 结合     v
# 补体     gb
# 的     ude1
# 能力     n
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 通常     d
# 是     vshi
# IM     nx
# 免疫球蛋白     gb
# ，     w
# 但     c
# 有些     rz
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 却是     d
# IG     nx
# 免疫球蛋白     gb
# 如有     c
# 的     ude1
# 抗     v
# Lea     nx
# ，     w
# 抗     v
# M     nx
# 、     w
# 抗     v
# N     nx
# 及     cc
# 抗     v
# K     nx
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 是     vshi
# IG     nx
# 免疫性     n
# 抗体     n
# 则     d
# 是     vshi
# 指     v
# 机体     n
# 受     v
# 同种     r
# 或     c
# 异种     nz
# 抗原刺激     gb
# 后     f
# 处于     v
# 超免疫     v
# 状态     n
# 而     cc
# 产生     v
# 的     ude1
# 抗体     n
# 输血     vi
# 、     w
# 妊娠     vi
# 是     vshi
# 产生     v
# 同种     r
# 免疫抗体     gb
# 的     ude1
# 主要     b
# 原因     n
# 接受     v
# 菌苗     n
# 、     w
# 抗血清     gb
# （     w
# 白喉     nhd
# 、     w
# 破伤风     nhd
# 抗毒素     n
# ）     w
# 注射     v
# ，     w
# 以及     cc
# 使用     v
# 过     uguo
# 猪     nf
# 的     ude1
# 胃     n
# 、     w
# 肝     n
# 浸液     nz
# 的     ude1
# 人     n
# ，     w
# 血清     n
# 中的     v
# 抗     v
# A     nx
# 、     w
# 抗     v
# B     nx
# 效价     gb
# 升高     v
# ，     w
# 是     vshi
# 异种     nz
# 免疫     vn
# 引起     v
# 的     ude1
# 免疫性     n
# 抗体     n
# 的     ude1
# 例子     n
# 免疫性     n
# 抗     v
# A     nx
# 及     cc
# 抗     v
# B     nx
# ，     w
# 在     p
# 许多     m
# 方面     n
# 与     cc
# “     w
# 天然     b
# 抗     v
# 体     ng
# ”     w
# 不同     a
# 有的     rz
# 抗体     n
# 与其     c
# 相应     vi
# 的     ude1
# 抗原     n
# 细胞     n
# 在     p
# 盐水     n
# 介质     n
# 中     f
# 即可     v
# 出现     v
# 凝集     v
# ，     w
# 这样     rzv
# 的     ude1
# 抗体     n
# 称为     v
# 完全     ad
# 抗体     n
# ；     w
# 有的     rz
# 抗体     n
# 在     p
# 盐水     n
# 介质     n
# 中     f
# 只能     v
# 与     cc
# 其     rz
# 相应     vi
# 的     ude1
# 抗原     n
# 细胞     n
# 结合     v
# （     w
# 致敏     gb
# ）     w
# ，     w
# 但     c
# 不能     v
# 出现     v
# 凝集     v
# ，     w
# 这样     rzv
# 的     ude1
# 抗体     n
# 称为     v
# 不     d
# 完全     ad
# 抗体     n
# 欲     d
# 使     v
# 不     d
# 完全     ad
# 抗体     n
# 与其     c
# 相应     vi
# 的     ude1
# 抗原     n
# 细胞     n
# 出现     v
# 凝集     v
# ，     w
# 还     d
# 需     v
# 借助     v
# 其他     rzv
# 介质     n
# ，     w
# 如     v
# 酶     nz
# 处理     vn
# 红细胞     n
# ，     w
# 或     c
# 将     d
# 红细胞     n
# 悬浮     vn
# 在     p
# 大分子     n
# 胶     n
# 体液     n
# 中     f
# ，     w
# 或     c
# 利用     v
# 抗     v
# 球蛋白     n
# 血清     n
# 的     ude1
# 帮助     v
# 实际上     d
# 完全     ad
# 抗体     n
# 一般     ad
# 是     vshi
# 指     v
# IM     nx
# 类型     n
# 的     ude1
# 抗体     n
# ，     w
# 而     cc
# 不     d
# 完全     ad
# 抗体     n
# 多     a
# 为     p
# IG     nx
# 类     q
# 别的     rzv
# 抗体     n
# IA     nx
# 主要     b
# 在     p
# 分泌液     nz
# 中     f
# ，     w
# 在     p
# 血型     n
# 抗体     n
# 中     f
# 不     d
# 占     v
# 主要     b
# 位置     n
# ABO     nx
# 、     w
# MN     nx
# 和     cc
# HLA     nx
# 等     udeng
# 血型     n
# 的     ude1
# 结构     n
# 和     cc
# 功能     n
# ABO     nx
# 血型     n
# 可     v
# 分为     v
# A     nx
# 、     w
# B     nx
# 、     w
# AB     nx
# 和     cc
# O     nx
# 型     k
# 等     udeng
# 4     m
# 种     q
# 血型     n
# 红细胞     n
# 含     v
# A     nx
# 抗原     n
# 和     cc
# H     nx
# 抗原     n
# 的     ude1
# 叫做     v
# A     nx
# 型     k
# ，     w
# A     nx
# 型     k
# 的     ude1
# 人     n
# 血清     n
# 中     f
# 含有     v
# 抗     v
# B     nx
# 抗体     n
# ；     w
# 红细胞     n
# 含     v
# B     nx
# 抗原     n
# 和     cc
# H     nx
# 抗原     n
# 的     ude1
# 叫做     v
# B     nx
# 型     k
# ，     w
# B     nx
# 型     k
# 的     ude1
# 人     n
# 血清     n
# 中     f
# 含有     v
# 抗     v
# A     nx
# 抗体     n
# ；     w
# 红细胞     n
# 含     v
# A     nx
# 抗原     n
# 、     w
# B     nx
# 抗原     n
# 和     cc
# H     nx
# 抗原     n
# ，     w
# 叫做     v
# AB     nx
# 型     k
# ，     w
# 这种     r
# 血型     n
# 的     ude1
# 人     n
# 血清     n
# 中     f
# 没有     v
# 抗     v
# A     nx
# 抗体     n
# 和     cc
# 抗     v
# B     nx
# 抗体     n
# ；     w
# 红细胞     n
# 只有     c
# H     nx
# 抗原     n
# ，     w
# 叫做     v
# O     nx
# 型     k
# ，     w
# O     nx
# 型     k
# 的     ude1
# 人     n
# 血清     n
# 中     f
# 含有     v
# 抗     v
# A     nx
# 抗体     n
# 和     cc
# 抗     v
# B     nx
# 抗体     n
# ABO     nx
# 血型     n
# 物质     n
# 除     p
# 存在     v
# 于     p
# 红细胞     n
# 膜     n
# 上外     nit
# ，     w
# 还     d
# 出现     v
# 于     p
# 唾液     n
# 、     w
# 胃液     n
# 、     w
# 精液     n
# 等     udeng
# 分泌液     nz
# 中     f
# 中国     ns
# 60     m
# ％     w
# 汉族人     nz
# 唾液     n
# 中     f
# 有     vyou
# ABO     nx
# 血型     n
# 物质     n
# 血型     n
# 物质     n
# 的     ude1
# 化学     n
# 本质     n
# 是     vshi
# 指     v
# 构成     v
# 血型     n
# 抗原     n
# 的     ude1
# 糖蛋白     gb
# 或     c
# 糖脂     gb
# ，     w
# 而     cc
# 血型     n
# 的     ude1
# 特异性     gb
# 主要     b
# 取决于     v
# 血型     n
# 抗原     n
# 糖     n
# 链     ng
# 的     ude1
# 组成     v
# （     w
# 即     v
# 血型     n
# 抗原     n
# 的     ude1
# 决定簇     gb
# 在     p
# 糖     n
# 链     ng
# 上     f
# ）     w
# A     nx
# 、     w
# B     nx
# 、     w
# H     nx
# 3     m
# 种     q
# 血型     n
# 抗原     n
# 化学     n
# 结构     n
# 的     ude1
# 差异     n
# ，     w
# 仅     d
# 在于     v
# 糖     n
# 链     ng
# 末端     n
# 的     ude1
# 1     m
# 个     q
# 单糖     n
# A     nx
# 抗原     n
# 糖     n
# 链     ng
# 末端     n
# 为     p
# N-     nx
# 乙酰     gb
# 半     mq
# 乳糖     n
# ，     w
# 而     cc
# B     nx
# 抗原     n
# 糖     n
# 链     ng
# 末端     n
# 为     p
# 半     mq
# 乳糖     n
# ，     w
# H     nx
# 抗原     n
# 和     cc
# A     nx
# 、     w
# B     nx
# 抗原     n
# 相比     vi
# 则     d
# 糖     n
# 链     ng
# 末端     n
# 少     a
# 1     m
# 个     q
# 半乳糖     nmc
# 或     c
# N-     nx
# 乙酰     gb
# 半乳糖     nmc
# 1981     m
# 年     qt
# 已     d
# 有人     r
# 用     p
# 绿     a
# 咖啡豆     nf
# 酶     nz
# （     w
# 半乳糖     nmc
# 苷     nz
# 酶     nz
# ）     w
# 作用于     v
# B     nx
# 型     k
# 红细胞     n
# ，     w
# 切去     v
# B     nx
# 抗原     n
# 上     f
# 的     ude1
# 半     mq
# 乳糖     n
# ，     w
# 从而     c
# 使     v
# B     nx
# 型     k
# 转变成     l
# O     nx
# 型     k
# 获得成功     l
# E     nx
# ．     w
# vo     nx
# 邓     nz
# 格     b
# 恩     ng
# 及     cc
# L     nx
# ．     w
# 希尔斯     nrf
# 费尔德     nrf
# 于     p
# 1911     m
# 年     qt
# 发现     v
# A     nx
# 血型     n
# 的     ude1
# 亚型     n
# 他们     rr
# 看到     v
# 不同     a
# A     nx
# 型     k
# 人     n
# 的     ude1
# 红细胞     n
# 与     cc
# 抗     v
# A     nx
# 血清     n
# 发生     v
# 凝集反应     nz
# 的     ude1
# 强度     n
# 不一     vi
# ，     w
# 在     p
# 反应     vn
# 弱     a
# 的     ude1
# A     nx
# 型     k
# 人     n
# 血清     n
# 中     f
# 还有     v
# 一     m
# 种     q
# 抗体     n
# 能     v
# 与     cc
# 反应     vn
# 强     a
# 的     ude1
# A     nx
# 型     k
# 红细胞     n
# 发生     v
# 凝集反应     nz
# 据此     d
# 认为     v
# 在     p
# A     nx
# 型     k
# 中     f
# 存在     v
# 亚型     n
# ；     w
# 即     v
# A     nx
# 1     m
# 及     cc
# A     nx
# 2     m
# 亚型     n
# A     nx
# 1     m
# .     w
# 型     k
# 红细胞     n
# 与     cc
# 抗     v
# A     nx
# 血清     n
# （     w
# 来自     v
# B     nx
# 或     c
# O     nx
# 型     k
# 人     n
# ）     w
# 反应     vn
# 强     a
# ，     w
# 而     cc
# A     nx
# 2     m
# 型     k
# 红细胞     n
# 与     cc
# 抗     v
# A     nx
# 血清     n
# 反应     vn
# 弱     a
# 而且     c
# 在     p
# 部分     n
# A     nx
# 2     m
# 型     k
# 人     n
# 的     ude1
# 血清     n
# 中     f
# ，     w
# 除     p
# 存在     v
# 的     ude1
# 抗     v
# B     nx
# 外     f
# ，     w
# 还有     v
# 不规则     a
# 的     ude1
# 抗     v
# A     nx
# 1     m
# 在     p
# B     nx
# 型     k
# 人     n
# 血清     n
# 中     f
# 有     vyou
# 两     m
# 种     q
# 抗体     n
# ：     w
# 抗     v
# A     nx
# 及     cc
# 抗     v
# A     nx
# 1     m
# 抗     v
# A     nx
# 能     v
# 与     cc
# A     nx
# 1     m
# 及     cc
# A     nx
# 2     m
# 细胞     n
# 发生     v
# 反应     vn
# ；     w
# 抗     v
# A     nx
# 1     m
# 只     d
# 与     cc
# A     nx
# 1     m
# 细胞     n
# 发生     v
# 反应     vn
# A     nx
# 1     m
# 型     k
# 红细胞     n
# 上     f
# 有     vyou
# A     nx
# 及     cc
# A     nx
# 1     m
# 两     m
# 种     q
# 抗原     n
# A     nx
# 2     m
# 细胞     n
# 上     f
# 只有     c
# A     nx
# 抗原     n
# AB     nx
# 型     k
# 也     d
# 可     v
# 分为     v
# A     nx
# 1     m
# B     nx
# 及     cc
# A     nx
# 2     m
# B     nx
# 等     udeng
# 亚型     n
# 此外     c
# 还有     v
# 一些     m
# 其他     rzv
# 亚型     n
# MN     nx
# 血型     n
# 红细胞     n
# 膜     n
# 上     f
# 另     rz
# 一类     b
# 血型     n
# 抗原     n
# 叫     vi
# MN     nx
# 抗原     n
# ，     w
# 即     v
# 红细胞     n
# 膜     n
# 上     f
# 的     ude1
# 血型     n
# 糖蛋白     gb
# A     nx
# 它     rr
# 在     p
# SOS     nx
# 凝胶电泳     gb
# 谱     ng
# 上     f
# 显示     v
# 两     m
# 条     q
# 区带     n
# ，     w
# 即     v
# PAS     nx
# －     w
# 1     m
# 和     cc
# PAS     nx
# －     w
# 2     m
# ，     w
# 血型     n
# 糖蛋白     gb
# A     nx
# 是     vshi
# 两者     rzv
# 的     ude1
# 二     m
# 聚     v
# 物     ng
# 已知     nz
# 血型     n
# 糖蛋白     gb
# A     nx
# 由     p
# 131     m
# 个     q
# 氨基酸组成     gb
# ，     w
# 其     rz
# 一级     b
# 结构     n
# 已     d
# 测定     v
# （     w
# 图     n
# 2     m
# ）     w
# 血型     n
# 糖蛋白     gb
# A     nx
# 的     ude1
# 肽链     gb
# 呈     v
# 三节     n
# 式     k
# 结构     n
# ，     w
# 中间     f
# 第     mq
# 73     m
# ～     w
# 92     m
# 号     q
# 氨基酸     n
# 为     p
# 疏水     nz
# 性     ng
# 肽链     gb
# ，     w
# 可     v
# 横穿     v
# 膜     n
# 脂     n
# 层     qv
# ；     w
# N     nx
# 端肽     n
# 链     ng
# 位于     v
# 膜     n
# 外侧     f
# ，     w
# 与     cc
# 血型     n
# 活性     b
# 有关     vn
# ，     w
# 在     p
# 这段     r
# 肽链     gb
# 上     f
# 分布     vi
# 有     vyou
# 15     m
# 条     q
# O-     nx
# 糖苷键     gb
# 型     k
# 糖     n
# 链     ng
# 和     cc
# 1     m
# 条     q
# N-     nx
# 糖苷键     gb
# 型     k
# 糖     n
# 链     ng
# ，     w
# 糖     n
# 链     ng
# 中     f
# 唾液酸     gb
# 占     v
# 红细胞     n
# 膜     n
# 上     f
# 全部     m
# 唾液酸     gb
# 的     ude1
# 一半     mq
# 以上     f
# ；     w
# C     nx
# 端肽     n
# 链     ng
# 位于     v
# 膜     n
# 内侧     f
# ，     w
# 含     v
# 较多     d
# 酸性     n
# 氨基酸     n
# MN     nx
# 抗原     n
# 由     p
# M     nx
# 抗原     n
# 和     cc
# N     nx
# 抗原     n
# 两     m
# 部分     n
# 组成     v
# ，     w
# 如果     c
# 用     p
# 神经     n
# 氨酸     gb
# 酶     nz
# 将     d
# M     nx
# 抗原     n
# 切去     v
# 1     m
# 个     q
# 唾液酸     gb
# （     w
# N-     nx
# 乙酰     gb
# 神经氨酸     gb
# ）     w
# ，     w
# 则     d
# 为     p
# N     nx
# 抗原     n
# ，     w
# 如     v
# 再     d
# 切去     v
# 一个     mq
# 唾液酸     gb
# 则     d
# 抗原性     gb
# 完全     ad
# 失去     v
# MN     nx
# 抗原     n
# 的     ude1
# 抗原性     gb
# 还     d
# 和     cc
# 肽链     gb
# 上     f
# 的     ude1
# 氨基     n
# 有关     vn
# ，     w
# 若     c
# 将     d
# 氨基     n
# 用     p
# 乙酰基     gc
# 保护     vn
# 后     f
# 即     v
# 失去     v
# 抗原性     gb
# 白细胞     n
# 血型     n
# ——     w
# HLA     nx
# HLA     nx
# 是     vshi
# 人类     n
# 白细胞     n
# 抗原     n
# 中     f
# 最重要     nz
# 的     ude1
# 一类     b
# 与     cc
# 红细胞     n
# 血型     n
# 相比     vi
# ，     w
# 人们     n
# 对     p
# 白细胞     n
# 抗原     n
# 的     ude1
# 了解     v
# 较晚     d
# ，     w
# 人体     n
# 第     mq
# 一个     mq
# 白细胞     n
# 抗原     n
# Mac     nx
# 是     vshi
# 1958     m
# 年     qt
# 法国     nsf
# 科学家     nnt
# J     nx
# ．     w
# 多     a
# 塞     v
# 发现     v
# 的     ude1
# HLA     nx
# 是     vshi
# 人体     n
# 白细胞     n
# 抗原     n
# 的     ude1
# 英文     nz
# 缩写     n
# ，     w
# 已     d
# 发现     v
# HLA     nx
# 抗原     n
# 有     vyou
# 144     m
# 种     q
# 以上     f
# ，     w
# 这些     rz
# 抗原     n
# 分为     v
# A     nx
# 、     w
# B     nx
# 、     w
# C     nx
# 、     w
# D     nx
# 、     w
# DR     nx
# 、     w
# DQ     nx
# 和     cc
# DP     nx
# 7     m
# 个     q
# 系列     n
# ，     w
# 而且     c
# HLA     nx
# 在     p
# 其他     rzv
# 细胞     n
# 表面     n
# 上     f
# 也     d
# 存在     v
# HLA     nx
# 抗原     n
# 是     vshi
# 一     m
# 种     q
# 糖蛋白     gb
# （     w
# 含糖     nz
# 为     p
# 9     m
# ％     w
# ）     w
# ，     w
# 其     rz
# 分子结构     n
# 与     cc
# 免疫球蛋白     gb
# 极     d
# 相似     a
# （     w
# 图     n
# 3     m
# ）     w
# HLA     nx
# 分子     n
# 由     p
# 4     m
# 条     q
# 肽链     gb
# 组成     v
# （     w
# 含     v
# 2     m
# 条     q
# 轻链     gb
# 和     cc
# 2     m
# 条     q
# 重     a
# 链     ng
# ）     w
# ，     w
# 重     a
# 链     ng
# 上     f
# 连接     v
# 2     m
# 条     q
# 糖     n
# 链     ng
# HLA     nx
# 分子     n
# 部分     n
# 镶嵌     v
# 在     p
# 细胞膜     n
# 的     ude1
# 双     q
# 脂     n
# 层     qv
# 中     f
# ，     w
# 其     rz
# 插入     v
# 膜     n
# 的     ude1
# 部分     n
# 相当于     v
# 免疫球蛋白     gb
# IG     nx
# 的     ude1
# Fc     nx
# 区段     n
# ，     w
# 轻链     gb
# 为     p
# β     w
# -     nx
# 微     ag
# 球蛋白     n
# 由于     p
# 分子结构     n
# 上     f
# 的     ude1
# 相似     a
# ，     w
# 故     c
# HLA     nx
# 与     cc
# 有     vyou
# 保卫     v
# 功能     n
# 的     ude1
# 免疫     vn
# 防御     vn
# 系统     n
# 密切相关     v
# 此外     c
# ，     w
# HLA     nx
# 和     cc
# 红细胞     n
# 血型     n
# 一样     uyy
# 都     d
# 受     v
# 遗传     vn
# 规律     n
# 的     ude1
# 控制     vn
# 决定     v
# HLA     nx
# 型     k
# 的     ude1
# 基因     n
# 在     p
# 第     mq
# 6     m
# 对     p
# 染色体     n
# 上     f
# 每个     mq
# 人     n
# 分别     d
# 可     v
# 从     p
# 父母     n
# 获得     v
# 一     m
# 套     q
# 染色体     n
# ，     w
# 所以     c
# 一个     mq
# 人     n
# 可以     v
# 同时     c
# 查出     v
# A     nx
# 、     w
# B     nx
# 、     w
# C     nx
# 、     w
# D     nx
# 和     cc
# DR     nx
# 5     m
# 个     q
# 系列     n
# 中的     v
# 5     m
# ～     w
# 10     m
# 种     q
# 白细胞     n
# 型     k
# ，     w
# 因此     c
# 表现     v
# 出来     vf
# 的     ude1
# 各种     rz
# 白细胞     n
# 型     k
# 有     vyou
# 上     f
# 亿     m
# 种     q
# 之     uzhi
# 多     a
# 在     p
# 无     v
# 血缘关系     nz
# 的     ude1
# 人间     n
# 找出     v
# HLA     nx
# 相同     a
# 的     ude1
# 两     m
# 个     q
# 是     vshi
# 很     d
# 困难     an
# 的     ude1
# 但     c
# 同胞兄弟     nz
# 姊妹     n
# 之间     f
# 总是     d
# 有     vyou
# 1     m
# ／     w
# 4     m
# 机会     n
# HLA     nx
# 完全相同     nz
# 或     c
# 完全     ad
# 不同     a
# 因此     c
# 法医鉴定     nz
# 亲缘关系     gb
# 时     qt
# ，     w
# HLA     nx
# 测定     v
# 是     vshi
# 最     d
# 有力     a
# 的     ude1
# 工具     n
# 动物     n
# 的     ude1
# 血型     n
# 过去     vf
# 人们     n
# 认为     v
# 只有     c
# 人才     n
# 有     vyou
# 血型     n
# ，     w
# 现在     t
# 已知     nz
# 狗     n
# 、     w
# 鸡     n
# 和     cc
# 许多     m
# 动物     n
# 都     d
# 有     vyou
# 血型     n
# 系统     n
# 生长     v
# 在     p
# 美国     nsf
# 缅因     nsf
# 海湾     n
# 的     ude1
# 角鲨     nz
# 有     vyou
# 4     m
# 种     q
# 血型     n
# 大马哈鱼     n
# 至少     d
# 有     vyou
# 8     m
# 种     q
# 抗原     n
# 类型     n
# 或     c
# 类型     n
# 的     ude1
# 组合     vn
# 这些     rz
# 不同     a
# 类型     n
# 的     ude1
# 出现     v
# 通常     d
# 随     p
# 不同     a
# 地区     n
# 的     ude1
# 种群     n
# 而     cc
# 异     ag
# 家畜     n
# 也     d
# 有     vyou
# 血型     n
# ，     w
# 马有     nr
# 4     m
# 种     q
# ，     w
# 牛有     nr
# 3     m
# 种     q
# ，     w
# 猪     nf
# 也     d
# 有     vyou
# 4     m
# 种     q
# 灵长类     nz
# 的     ude1
# 血型     n
# 可以     v
# 通过     p
# 抗     v
# A     nx
# 和     cc
# 抗     v
# B     nx
# 血清     n
# 来     vf
# 测定     v
# 黑猩猩     n
# 的     ude1
# 血     n
# 全部     m
# 属于     v
# O     nx
# 型     k
# 或     c
# A     nx
# 型     k
# ，     w
# 猩猩     n
# 属于     v
# B     nx
# 型     k
# ，     w
# 大猩猩     n
# 有     vyou
# B     nx
# 型     k
# 也     d
# 有     vyou
# A     nx
# 型     k
# ，     w
# 长臂猿     n
# 血型     n
# 有     vyou
# A     nx
# 型     k
# 、     w
# B     nx
# 型     k
# 及     cc
# AB     nx
# 型     k
# 低等     b
# 灵长类     nz
# 在     p
# 红血球     n
# 里     f
# 没有     v
# 抗原     n
# ，     w
# 但     c
# 在     p
# 它们     rr
# 的     ude1
# 唾液     n
# 里     f
# 分泌     v
# ABO     nx
# 抗原     n
# 旧     a
# 大陆     ns
# 猴     ng
# 大多数     m
# 是     vshi
# 血型     n
# A     nx
# 型     k
# ，     w
# 新     a
# 大陆     ns
# 猴     ng
# 血型     n
# 也     d
# 是     vshi
# A     nx
# 型     k
# ，     w
# 但     c
# 个别     a
# 的     ude1
# 在     p
# 唾液     n
# 里     f
# 有     vyou
# 象     ng
# B     nx
# 一     m
# 样     ng
# 的     ude1
# 抗原     n
# 在     p
# 某些     rz
# 灵长类     nz
# 中     f
# 发现     v
# 具有     v
# 类似     a
# 人类     n
# M     nx
# 的     ude1
# 抗原     n
# ，     w
# 如     v
# 在     p
# 黑猩猩     n
# 体内     s
# 发现     v
# 了     ule
# 具有     v
# M     nx
# 血型     n
# 和     cc
# N     nx
# 血型     n
# ，     w
# 在     p
# 灵长类     nz
# 中     f
# 也     d
# 发现     v
# 具     vg
# Rh     nx
# 抗原     n
# 的     ude1
# 来源     n
# :     w
# 高中生物     nz
# 资源网     nz
# 2     m
# ;     w

# %%
# 这里是jieba分词
import re
import jieba
import jieba.posseg as pseg

jiebaList = [] # 创建一个列表保存jieba分词结果
print("--------------------对新闻进行jieba分词，分词后的结果是↓--------------------")
print('单词↓↓ 词性↓↓')

txtFiles = '95-预处理.txt'  # 待处理的文本（新闻）
with open(txtFiles, encoding='ANSI') as fp:
        for line in fp:
            line = re.sub(r'[\n]','',line) # 将line中的'\n'去掉
            # jieba分词处理
            # cut_all为False，为精准模式，为True是准确模式
            new = jieba.cut(line,cut_all=False)  # 精准分词
            all = ''.join(new)   # new 是generator object，将其变成字符串
            words = pseg.cut(all)    # 词性标注
            for word, flag in words:
                # 分词结果，单词 词性
                print('%s     %s' % (word, flag))
                jiebaList.append(word) # 将jieba分词结果保存在一个列表里面，后面做错误分析有用
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\MSI-PC\AppData\Local\Temp\jieba.cache
# --------------------对新闻进行jieba分词，分词后的结果是↓--------------------
# 单词↓↓ 词性↓↓
# Loading model cost 0.612 seconds.
# Prefix dict has been built successfully.
# ;     x
# 第一页     m
# 血型     n
# （     x
# lood     eng
#       x
# rou     eng
# ）     x
# 以     p
# 血液     n
# 抗原     n
# 形式     n
# 表现     v
# 出来     v
# 的     uj
# 一种     m
# 遗传性状     n
# 狭义     b
# 地     uv
# 讲     v
# ，     x
# 血型     n
# 专指     n
# 红细胞     n
# 抗原     n
# 在     p
# 个体     n
# 间     f
# 的     uj
# 差异     n
# ；     x
# 但     c
# 现已     d
# 知道     v
# 除     p
# 红细胞     n
# 外     f
# ，     x
# 在     p
# 白细胞     n
# 、     x
# 血小板     n
# 乃至     c
# 某些     r
# 血浆     n
# 蛋白     n
# ，     x
# 个体     n
# 之间     f
# 也     d
# 存在     v
# 着     uz
# 抗原     n
# 差异     n
# 因此     c
# ，     x
# 广义     ns
# 的     uj
# 血型     n
# 应     v
# 包括     v
# 血液     n
# 各     r
# 成分     n
# 的     uj
# 抗原     n
# 在     p
# 个体     n
# 间     f
# 出现     v
# 的     uj
# 差异     n
# 血型     n
# 在     p
# 人类学     n
# 、     x
# 遗传学     n
# 、     x
# 法医学     nt
# 、     x
# 临床医学     l
# 等     u
# 学科     n
# 都     d
# 有     v
# 广泛     a
# 的     uj
# 实用价值     l
# ，     x
# 因此     c
# 具有     v
# 重要     a
# 的     uj
# 理论     n
# 和     c
# 实践     v
# 意义     n
# 血型     n
# 系统     n
# 红细胞     n
# 血型     n
# 是     v
# 1900     m
# 年     m
# 由     p
# 奥地利     ns
# K     x
# ．     x
# 兰德     nrt
# 施泰纳     nr
# 发现     v
# 的     uj
# 他     r
# 把     p
# 每个     r
# 人     n
# 的     uj
# 红细胞     n
# 分别     d
# 与     p
# 别人     r
# 的     uj
# 血清     n
# 交叉     n
# 混合     vn
# 后     f
# ，     x
# 发现     v
# 有     v
# 的     uj
# 血液     n
# 之间     f
# 发生     v
# 凝集反应     n
# ，     x
# 有的     r
# 则     d
# 不     d
# 发生     v
# 他     r
# 认为     v
# 凡是     d
# 凝集     v
# 者     k
# ，     x
# 红细胞     n
# 上     f
# 有     v
# 一种     m
# 抗原     n
# ，     x
# 血清     n
# 中     f
# 有     v
# 一种     m
# 抗体     n
# 如     v
# 抗原     n
# 与     p
# 抗体     n
# 有     v
# 相对     d
# 应     v
# 的     uj
# 特异     a
# 关系     n
# ，     x
# 便     d
# 发生     v
# 凝集反应     n
# 如     v
# 红细胞     n
# 上有     v
# A     eng
# 抗原     n
# ，     x
# 血清     n
# 中     f
# 有     v
# A     eng
# 抗体     n
# ，     x
# 便     d
# 会     v
# 发生     v
# 凝集     v
# 如果     c
# 红细胞     n
# 缺乏     v
# 某     r
# 一种     m
# 抗原     n
# ，     x
# 或     c
# 血清     n
# 中     f
# 缺乏     v
# 与     p
# 之     f
# 对应     vn
# 的     uj
# 抗体     n
# ，     x
# 就     d
# 不     d
# 发生     v
# 凝集     v
# 根据     p
# 这个     r
# 原理     n
# 他     r
# 发现     v
# 了     ul
# 人     n
# 的     uj
# ABO     eng
# 血型     n
# 后来     t
# 他     r
# 又     d
# 把     p
# 不同     a
# 人     n
# 的     uj
# 红细胞     n
# 分别     d
# 注射     v
# 到     v
# 家兔     n
# 体内     s
# ，     x
# 在     p
# 家兔     n
# 血清     n
# 中     f
# 产生     n
# 了     ul
# 3     m
# 种     m
# 免疫性     n
# 抗体     n
# ，     x
# 分别     d
# 叫做     v
# M     x
# 抗体     n
# 、     x
# N     x
# 抗体     n
# 及     c
# P     eng
# 抗体     n
# 用     p
# 这     r
# 3     m
# 种     m
# 抗体     n
# ，     x
# 又     d
# 可     v
# 确定     v
# 红细胞     n
# 上     ns
# 3     m
# 种     m
# 新     a
# 的     uj
# 抗原     n
# 这些     r
# 新     a
# 的     uj
# 抗原     n
# 与     p
# ABO     eng
# 血型     n
# 无关     v
# ，     x
# 是     v
# 独立     v
# 遗传     vn
# 的     uj
# ，     x
# 是     v
# 另外     c
# 的     uj
# 血型     n
# 系统     n
# 而且     c
# M     x
# 、     x
# N     eng
# 与     p
# P     eng
# 也     d
# 不是     c
# 一个     m
# 系统     n
# 控制     v
# 不同     a
# 血型     n
# 系统     n
# 的     uj
# 血型     n
# 基因     n
# 在     p
# 不同     a
# 的     uj
# 染色体     n
# 上     f
# ，     x
# 即使     c
# 在     p
# 一个     m
# 染色体     n
# 上     f
# ，     x
# 两个     m
# 系统     n
# 的     uj
# 基因     n
# 位点     n
# 也     d
# 相距甚远     l
# ，     x
# 不是     c
# 连锁     vn
# 关系     n
# ，     x
# 因此     c
# 是     v
# 独立     v
# 遗传     vn
# 的     uj
# 有些     r
# 血型     n
# 抗体     n
# 是     v
# 不     d
# 完全     ad
# 抗体     n
# ，     x
# 与     p
# 相应     v
# 的     uj
# 抗原     n
# 细胞     n
# 结合     v
# 后     f
# 看不出     v
# 凝集     v
# 现象     n
# ，     x
# 血清     n
# 中     f
# 有     v
# 抗体     n
# 但     c
# 不     d
# 容易     a
# 发现     v
# 1945     m
# 年     m
# 抗人     n
# 球蛋白     l
# 试验     vn
# 应用     v
# 到     v
# 血型     n
# 检查     vn
# 中来     t
# ，     x
# 这种     r
# 试验     vn
# 就     d
# 可     v
# 检查     vn
# 不     d
# 完全     ad
# 抗体     n
# ，     x
# 从此     c
# ，     x
# 许多     m
# 血型     n
# 抗原     n
# 陆续     d
# 被     p
# 人     n
# 发现     v
# 每当     p
# 发现     v
# 一个     m
# 新     a
# 抗原     n
# 后     f
# 就要     d
# 确定     v
# 这     r
# 一     m
# 抗原     n
# 与     p
# 已经     d
# 发现     v
# 的     uj
# 血型     n
# 是     v
# 什么     r
# 关系     n
# ，     x
# 这样     r
# 在     p
# 人     n
# 的     uj
# 红细胞     n
# 上     f
# 便     d
# 确定     v
# 了     ul
# 若干     m
# 血型     n
# 系统     n
# 此外     c
# ，     x
# 还有     v
# 一些     m
# 抗原     n
# ，     x
# 或因其     c
# 在     p
# 群体     n
# 中     f
# 出现     v
# 的     uj
# 频率     n
# 太     d
# 高     a
# ，     x
# 或因其     c
# 在     p
# 群体     n
# 中     f
# 分布     v
# 的     uj
# 频率     n
# 太     d
# 低     a
# ，     x
# 对     p
# 它们     r
# 无法     n
# 进行     v
# 遗传学     n
# 分析     vn
# 在     p
# 没有     v
# 弄清     v
# 它们     r
# 的     uj
# 遗传     vn
# 关系     n
# 以前     f
# ，     x
# 暂且     d
# 把     p
# 这些     r
# 抗原     n
# 分别     d
# 叫做     v
# 高频率     n
# 抗原     n
# 及     c
# 低     a
# 频率     n
# 抗原     n
# ，     x
# 对于     p
# 它们     r
# 的     uj
# 归属     v
# 有待     v
# 进一步     d
# 确定     v
# 红细胞     n
# 血型     n
# 抗原     n
# 红     a
# 细胞膜     n
# 中     f
# 夹杂着     v
# 3     m
# 种     m
# 蛋白质     n
# ：     x
# 糖蛋白     n
# 、     x
# 简单     a
# 蛋白     n
# 及     c
# 膜     n
# 收缩     v
# 蛋白     n
# 红细胞     n
# 抗原     n
# 有些     r
# 突出     v
# 在     p
# 细胞     n
# 表面     n
# ，     x
# 好像     v
# 伸出     v
# 在     p
# 地面     n
# 上     f
# 的     uj
# 树枝     n
# ，     x
# 如     c
# ABH     eng
# 抗原     n
# ；     x
# 有些     r
# 镶嵌     v
# 在     p
# 细胞膜     n
# 内     n
# ，     x
# 如     c
# Rh     eng
# 抗原     n
# 抗原     n
# 与     p
# 抗体     n
# 发生     v
# 特异     a
# 反应     vn
# 的     uj
# 部分     n
# ，     x
# 叫做     v
# 抗原     n
# 决定簇     i
# 血型     n
# 抗原     n
# 决定簇     i
# 的     uj
# 化学     n
# 组成     v
# ，     x
# 有     v
# 的     uj
# 已经     d
# 清楚     a
# ，     x
# 但     c
# 大部分     m
# 不     d
# 清楚     a
# 有些     r
# 血型     n
# 在     p
# 体液     n
# 中     f
# 存在     v
# 可溶性     n
# 抗原     n
# ，     x
# 叫做     v
# 血型     n
# 物质     n
# 从     p
# 人体     n
# 分离出来     i
# 的     uj
# ABH     eng
# 及     c
# Lewi     eng
# 血型     n
# 物质     n
# 是     v
# 糖蛋白     n
# ，     x
# 即     v
# 在     p
# 肽链     n
# 的     uj
# 骨架     n
# 上     f
# 连接     v
# 着     uz
# 一些     m
# 糖     n
# 的     uj
# 侧链     n
# ，     x
# 这些     r
# 糖链     n
# 便是     v
# 特异性     n
# 决定簇     i
# ABH     eng
# 及     c
# Lewi     eng
# 血型     n
# 物质     n
# 的     uj
# 特异性     n
# 决定簇     i
# 很     zg
# 相似     v
# ，     x
# 只是     c
# 在     p
# 糖链     n
# 上     f
# 个别     n
# 糖     n
# 的     uj
# 种类     n
# 或同     c
# 一种     m
# 糖     zg
# 由于     c
# 存在     v
# 位置     v
# 不同     a
# ，     x
# 就     d
# 显出     v
# 不同     a
# 的     uj
# 特异性     n
# 比如     v
# A     eng
# 与     p
# B     eng
# 的     uj
# 抗原     n
# 特异性     n
# ，     x
# 只是     c
# 在     p
# 糖链     n
# 上     f
# 有     v
# 一个     m
# 糖     n
# 不     d
# 相同     d
# ，     x
# 便     d
# 显示     v
# 出     v
# 不同     a
# 的     uj
# 特异性     n
# A     x
# 抗原     n
# 决定簇     i
# 在     p
# 糖链     n
# 的     uj
# 终     n
# 末端     f
# 是     v
# 一个     m
# N     x
# -     x
# 乙酰     n
# 半乳糖     n
# 胺     n
# ，     x
# 而     c
# B     eng
# 抗原     n
# 决定簇     i
# 在     p
# 糖链     n
# 的     uj
# 终     n
# 末端     f
# 却是     d
# 一个     m
# D     x
# -     x
# 半乳糖     n
# 红细胞     n
# 上     f
# 的     uj
# ABH     eng
# 抗原     n
# 决定簇     i
# ，     x
# 虽     c
# 与     p
# 体液     n
# 中     f
# 的     uj
# 抗原     n
# 决定簇     i
# 糖链     n
# 结构     n
# 相同     d
# ，     x
# 但     c
# 连接     v
# 的     uj
# 骨架     n
# 不同     a
# 红细胞     n
# 上     f
# 的     uj
# 糖链     n
# 是     v
# 通过     p
# 神经     n
# 鞘氨醇     n
# 与     p
# 脂肪酸     n
# 结合     v
# 在     p
# 一起     m
# ，     x
# 而     c
# 不是     c
# 与     p
# 蛋白质     n
# 结合     v
# 在     p
# 一起     m
# ，     x
# 所以     c
# 红细胞     n
# 上     f
# 的     uj
# ABH     eng
# 抗原     n
# 是     v
# 糖脂     n
# 而     c
# 不是     c
# 糖蛋白     n
# MN     eng
# ·     x
# P     eng
# 及     c
# I     eng
# 血型     n
# 的     uj
# 抗原     n
# 决定簇     i
# 也     d
# 是     v
# 碳水化合物     n
# Rh     eng
# 抗原     n
# 的     uj
# 决定簇     i
# 可能     v
# 是     v
# 蛋白质     n
# ，     x
# 因为     c
# 红细胞     n
# 经硫     n
# 氢化物     n
# 、     x
# 脲素     nz
# 及     c
# 蛋白酶     n
# 等物     n
# 处理     v
# 后     f
# ，     x
# Rh     eng
# 活性     n
# 即     v
# 行     zg
# 消失     n
# 有     v
# 一些     m
# 血型     n
# 抗体     n
# ，     x
# 如     v
# 抗     v
# IH     eng
# ，     x
# 抗     nz
# IA     eng
# ，     x
# 抗     nz
# IB     eng
# ，     x
# 抗     nz
# IP1     eng
# 等     u
# ，     x
# 只     d
# 与     p
# 带有     v
# I     x
# 抗原     n
# 及     c
# 另外     c
# 一个     m
# 抗原     n
# 的     uj
# 细胞     n
# 发生     v
# 反应     vn
# ，     x
# 而     c
# 不     d
# 与     p
# 其中     r
# 只有     c
# 一个     m
# 抗原     n
# 的     uj
# 细胞     n
# 发生     v
# 反应     vn
# 说明     v
# 这些     r
# 抗原     n
# 为     p
# 复合     v
# 抗原     n
# ，     x
# 在     p
# 一个     m
# 分子     n
# 上     f
# 具有     v
# 两种     m
# 特异性     n
# Lewi     eng
# 血型     n
# 抗原     n
# 实际上     d
# 是     v
# 血浆     n
# 中     f
# 的     uj
# 抗原     n
# ，     x
# 红细胞     n
# 上     f
# 的     uj
# Lewi     eng
# 抗原     n
# 是从     v
# 血浆     n
# 中     f
# 吸附     v
# 来     v
# 的     uj
# I     x
# 抗原     n
# 在     p
# 分泌液     n
# 中     f
# 虽有     c
# 可溶性     n
# 抗原     n
# ，     x
# 但     c
# 不     d
# 存在     v
# 于     p
# 血浆     n
# 中     f
# 另外     c
# 有些     r
# 血型     n
# 是     v
# 在     p
# 血浆     n
# 中     f
# 存在     v
# 可溶性     n
# 抗原     n
# ，     x
# 分泌液     n
# 中     f
# 却     d
# 不     d
# 存在     v
# B     x
# 抗原     n
# 实际     n
# 是     v
# 白细胞     n
# 的     uj
# 抗原     n
# ，     x
# 可能     v
# 从     p
# 白细胞     n
# 脱落     v
# 到     v
# 血浆     n
# 中     f
# ，     x
# 再     d
# 从     p
# 血浆     n
# 中     f
# 吸附     v
# 到     v
# 红细胞     n
# 上     f
# ，     x
# 表现     v
# 为     p
# 红细胞     n
# 的     uj
# 抗原     n
# Chido     eng
# 血型     n
# 及     c
# Roder     eng
# 血型     n
# 的     uj
# 抗原     n
# 与     p
# 血浆     n
# 中     f
# 的     uj
# 补体     n
# 第四     m
# 成分     n
# （     x
# C4     eng
# ）     x
# 有关     vn
# 用     p
# 电泳     n
# 方法     n
# 分析     vn
# 人     n
# 的     uj
# C4     eng
# ，     x
# 可以     c
# 见到     v
# 3     m
# 种     m
# 类型     n
# ：     x
# 泳动     n
# 快     a
# 的     uj
# （     x
# F     x
# ）     x
# ；     x
# 泳动     n
# 慢     a
# 的     uj
# （     x
# S     x
# ）     x
# ；     x
# 快慢     d
# 两种     m
# 成份     n
# 都     d
# 有     v
# 的     uj
# （     x
# FS     eng
# ）     x
# 血浆     n
# 中     f
# 只有     c
# F     x
# 成份     n
# 的     uj
# 人     n
# ，     x
# 红细胞     n
# 上有     v
# Roder     eng
# 抗原     n
# 只有     c
# S     x
# 成份     n
# 的     uj
# 人     n
# ，     x
# 红细胞     n
# 上有     v
# Chido     eng
# 抗原     n
# 两种     m
# 成份     n
# 全有     b
# 的     uj
# 人     n
# ，     x
# 红细胞     n
# 上     f
# 也     d
# 同时     c
# 具有     v
# Chido     eng
# 及     c
# Roder     eng
# 两种     m
# 抗原     n
# 各种     r
# 血型     n
# 抗原     n
# 在     p
# 红细胞     n
# 上     f
# 的     uj
# 分布     v
# 是     v
# 不同     a
# 的     uj
# ，     x
# 有     v
# 的     uj
# 密集     n
# ，     x
# 有     v
# 的     uj
# 疏松     a
# 抗原     n
# 数目     n
# 的     uj
# 多少     m
# 决定     v
# 了     ul
# 抗原     n
# 的     uj
# 强弱     a
# 用     p
# 放射性     n
# 碘     n
# 标记     n
# 的     uj
# 兔抗     n
# A     eng
# 及     c
# 抗     v
# B     eng
# 血清     n
# ，     x
# 检查     vn
# 人     n
# 的     uj
# 红细胞     n
# ，     x
# 根据     p
# 每个     r
# 细胞     n
# 上     f
# 的     uj
# 放射性     n
# 强度     n
# ，     x
# 可     v
# 推算出     v
# 每个     r
# 红细胞     n
# 上     f
# 的     uj
# 抗原     n
# 数目     n
# 各种     r
# 血型     n
# 抗原     n
# 在     p
# 个体发育     l
# 不同     a
# 阶段     n
# 强度     n
# 是     v
# 不     d
# 相同     d
# 的     uj
# 新生儿     n
# 的     uj
# ABO     eng
# 及     c
# Lewi     eng
# 抗原     n
# 与其     c
# 相应     v
# 的     uj
# 抗体     n
# 之     u
# 反应     vn
# 较     zg
# 成人     n
# 细     a
# 脆弱     a
# 不到     v
# 10     m
# 厘米     q
# 的     uj
# 胎儿     n
# 之     u
# 红细胞     n
# 就     d
# 能     v
# 与     p
# 抗     nz
# P1     eng
# 血清     n
# 发生     v
# 反应     vn
# ，     x
# 但其     c
# 反应     vn
# 强度     n
# 较     zg
# 成人     n
# 红细胞     n
# 弱     a
# 新生儿     n
# 的     uj
# 红细胞     n
# 吸收     v
# 抗     nz
# I     eng
# 的     uj
# 能力     n
# 几乎     d
# 与     p
# 成人     n
# 红细胞     n
# 一样     r
# ，     x
# 但     c
# 凝集反应     n
# 强度     n
# 远较     d
# 成人     n
# 红细胞     n
# 弱     a
# 可是     c
# 与     p
# 抗     nz
# i     eng
# 血清     n
# 的     uj
# 凝集     v
# 却     d
# 比     p
# 成人     n
# 红细胞     n
# 强     a
# Ya     eng
# 及     c
# Xa     eng
# 抗原     n
# 在     p
# 新生儿     n
# 红细胞     n
# 上     f
# 稍较     d
# 成人     n
# 红细胞     n
# 弱     a
# ，     x
# 而     c
# Rh     eng
# 、     x
# Kell     eng
# 、     x
# Duffy     eng
# 、     x
# Jk     eng
# 、     x
# MNS     eng
# 、     x
# Di     eng
# 及     c
# Do     eng
# 等     u
# 系统     n
# 的     uj
# 抗原     n
# 在     p
# 出生     v
# 时     ng
# 已     d
# 发育     vn
# 完全     ad
# Chido     eng
# 血型     n
# 的     uj
# 抗原     n
# 在     p
# 新生儿     n
# 血浆     n
# 中     f
# 可以     c
# 检出     v
# ，     x
# 但     c
# 在     p
# 红细胞     n
# 上     f
# 不能     v
# 发现     v
# 血型     n
# 抗体     n
# 抗体     n
# 是     v
# 免疫     v
# 球蛋白     l
# ，     x
# 但     c
# 不     d
# 一定     d
# 所有     b
# 免疫     v
# 球蛋白     l
# 都     d
# 是     v
# 抗体     n
# 只要     c
# 具有     v
# 抗体     n
# 结构     n
# 的     uj
# 糖蛋白     n
# 便     d
# 为     p
# 免疫     v
# 球蛋白     l
# 免疫     v
# 球蛋白     l
# 以     p
# I     eng
# 表示     v
# ，     x
# 现已     d
# 发现     v
# 人类     n
# 具有     v
# 五类     m
# 免疫     v
# 球蛋白     l
# ，     x
# 分别     d
# 叫做     v
# IG     eng
# 、     x
# IM     eng
# 、     x
# IA     eng
# 、     x
# ID     eng
# 及     c
# IE     eng
# 与     p
# 血型     n
# 有关     vn
# 的     uj
# 免疫     v
# 球蛋白     l
# 只有     c
# 三类     m
# ，     x
# 即     c
# IG     eng
# 、     x
# IM     eng
# 及     c
# IA     eng
# 三类     m
# 根据     p
# 抗体     n
# 在     p
# 体内     s
# 出现     v
# 是否     v
# 有     v
# 可     v
# 查觉     v
# 的     uj
# 抗原刺激     l
# ，     x
# 有     v
# 所谓     b
# “     x
# 天然     b
# 抗体     n
# ”     x
# 及     c
# “     x
# 免疫性     n
# 抗体     n
# ”     x
# 之     u
# 分     v
# 凡     d
# 未经     d
# 抗原刺激     l
# 就     d
# 在     p
# 体内     s
# 的     uj
# 血清     n
# 中     f
# 出现     v
# 的     uj
# 抗体     n
# ，     x
# 叫做     v
# “     x
# 天然     b
# 抗体     n
# ”     x
# ；     x
# 机体     n
# 受     v
# 同种     r
# 或     c
# 异种     n
# 抗原     n
# 的     uj
# 刺激     v
# 后     f
# 血清     n
# 中     f
# 所     c
# 产生     n
# 的     uj
# 抗体     n
# ，     x
# 叫作     v
# 免疫性     n
# 抗体     n
# 对于     p
# “     x
# 天然     b
# 抗体     n
# ”     x
# 的     uj
# 产生     n
# 有     v
# 两种     m
# 解释     v
# ：     x
# 一种     m
# 说法     v
# 认为     v
# 在     p
# 体内     s
# 存在     v
# “     x
# 抗原     n
# 致敏     v
# ”     x
# 细胞     n
# ，     x
# 不     d
# 需要     v
# 抗原刺激     l
# 就     d
# 能     v
# 产生     n
# 特异性     n
# 抗体     n
# ；     x
# 另     r
# 一种     m
# 解释     v
# 认为     v
# “     x
# 天然     b
# 抗体     n
# ”     x
# 是     v
# 异种     n
# 凝集素     n
# ，     x
# 周围环境     l
# 存在     v
# 着     uz
# 一些     m
# 与     p
# 血型     n
# 抗原     n
# 相似     v
# 的     uj
# 物质     n
# ，     x
# 机体     n
# 接触     v
# 这些     r
# 物质     n
# 后     f
# ，     x
# 所     c
# 产生     n
# 的     uj
# 交叉     n
# 反应     vn
# 抗体     n
# 比如     v
# 某些     r
# 细菌     n
# 含有     v
# 与     p
# 人     n
# 的     uj
# A     eng
# ，     x
# B     x
# 抗原     n
# 相似     v
# 的     uj
# 抗原     n
# ，     x
# 当     t
# 人们     n
# 吸入     v
# 或     c
# 吞下     v
# 这些     r
# 细菌     n
# 后     f
# ，     x
# 便     d
# 产生     n
# 交叉     n
# 反应     vn
# 抗体     n
# 第二页     m
# “     x
# 天然     b
# 抗体     n
# ”     x
# 在     p
# 低温     n
# 与其     c
# 相应     v
# 的     uj
# 抗原     n
# 细胞     n
# 反应     vn
# 强     a
# ，     x
# 有     v
# 很多     m
# “     x
# 天然     b
# 抗体     n
# ”     x
# 当     t
# 温度     n
# 超过     v
# 25     m
# ℃     x
# 时     ng
# 即     v
# 无     v
# 活性     n
# 有     v
# 的     uj
# “     x
# 天然     b
# 抗体     n
# ”     x
# 有     v
# 结合     v
# 补体     n
# 的     uj
# 能力     n
# ，     x
# 有的     r
# 则     d
# 没有     v
# 如     c
# Lewi     eng
# 血型     n
# 抗体     n
# 几乎     d
# 都     d
# 有     v
# 结合     v
# 补体     n
# 的     uj
# 能力     n
# ，     x
# 而     c
# 抗     v
# M     eng
# 及     c
# 抗     v
# N     eng
# 就     d
# 没有     v
# 结合     v
# 补体     n
# 的     uj
# 能力     n
# “     x
# 天然     b
# 抗体     n
# ”     x
# 通常     d
# 是     v
# IM     eng
# 免疫     v
# 球蛋白     l
# ，     x
# 但     c
# 有些     r
# “     x
# 天然     b
# 抗体     n
# ”     x
# 却是     d
# IG     eng
# 免疫     v
# 球蛋白     l
# 如有     v
# 的     uj
# 抗     vn
# Lea     eng
# ，     x
# 抗     nz
# M     eng
# 、     x
# 抗     nz
# N     eng
# 及     c
# 抗     v
# K     eng
# “     x
# 天然     b
# 抗体     n
# ”     x
# 是     v
# IG     eng
# 免疫性     n
# 抗体     n
# 则     d
# 是     v
# 指     n
# 机体     n
# 受     v
# 同种     r
# 或     c
# 异种     n
# 抗原刺激     l
# 后     f
# 处于     v
# 超免疫     v
# 状态     n
# 而     c
# 产生     n
# 的     uj
# 抗体     n
# 输血     v
# 、     x
# 妊娠     v
# 是     v
# 产生     n
# 同种     r
# 免疫抗体     n
# 的     uj
# 主要     b
# 原因     n
# 接受     v
# 菌苗     n
# 、     x
# 抗血清     l
# （     x
# 白喉     n
# 、     x
# 破伤风     i
# 抗毒素     nz
# ）     x
# 注射     v
# ，     x
# 以及     c
# 使用     v
# 过     ug
# 猪     n
# 的     uj
# 胃     n
# 、     x
# 肝     n
# 浸液     n
# 的     uj
# 人     n
# ，     x
# 血清     n
# 中     f
# 的     uj
# 抗     vn
# A     eng
# 、     x
# 抗     nz
# B     eng
# 效价     n
# 升高     v
# ，     x
# 是     v
# 异种     n
# 免疫     v
# 引起     v
# 的     uj
# 免疫性     n
# 抗体     n
# 的     uj
# 例子     n
# 免疫性     n
# 抗     nz
# A     eng
# 及     c
# 抗     v
# B     eng
# ，     x
# 在     p
# 许多     m
# 方面     n
# 与     p
# “     x
# 天然     b
# 抗体     n
# ”     x
# 不同     a
# 有     v
# 的     uj
# 抗体     n
# 与其     c
# 相应     v
# 的     uj
# 抗原     n
# 细胞     n
# 在     p
# 盐水     n
# 介质     n
# 中     f
# 即可     d
# 出现     v
# 凝集     v
# ，     x
# 这样     r
# 的     uj
# 抗体     n
# 称为     v
# 完全     ad
# 抗体     n
# ；     x
# 有     v
# 的     uj
# 抗体     n
# 在     p
# 盐水     n
# 介质     n
# 中     f
# 只能     v
# 与其     c
# 相应     v
# 的     uj
# 抗原     n
# 细胞     n
# 结合     v
# （     x
# 致敏     v
# ）     x
# ，     x
# 但     c
# 不能     v
# 出现     v
# 凝集     v
# ，     x
# 这样     r
# 的     uj
# 抗体     n
# 称为     v
# 不     d
# 完全     ad
# 抗体     n
# 欲     d
# 使     v
# 不     d
# 完全     ad
# 抗体     n
# 与其     c
# 相应     v
# 的     uj
# 抗原     n
# 细胞     n
# 出现     v
# 凝集     v
# ，     x
# 还     d
# 需     v
# 借助     v
# 其他     r
# 介质     n
# ，     x
# 如     v
# 酶     n
# 处理     v
# 红细胞     n
# ，     x
# 或     c
# 将     d
# 红细胞     n
# 悬浮     v
# 在     p
# 大分子     n
# 胶体     n
# 液     ng
# 中     f
# ，     x
# 或     c
# 利用     n
# 抗     v
# 球蛋白     l
# 血清     n
# 的     uj
# 帮助     v
# 实际上     d
# 完全     ad
# 抗体     n
# 一般     a
# 是     v
# 指     n
# IM     eng
# 类型     n
# 的     uj
# 抗体     n
# ，     x
# 而     c
# 不     d
# 完全     ad
# 抗体     n
# 多     m
# 为     p
# IG     eng
# 类别     n
# 的     uj
# 抗体     n
# IA     eng
# 主要     b
# 在     p
# 分泌液     n
# 中     f
# ，     x
# 在     p
# 血型     n
# 抗体     n
# 中     f
# 不     d
# 占     v
# 主要     b
# 位置     v
# ABO     eng
# 、     x
# MN     eng
# 和     c
# HLA     eng
# 等     u
# 血型     n
# 的     uj
# 结构     n
# 和     c
# 功能     n
# ABO     eng
# 血型     n
# 可     v
# 分为     v
# A     x
# 、     x
# B     x
# 、     x
# AB     eng
# 和     c
# O型     n
# 等     u
# 4     m
# 种     m
# 血型     n
# 红细胞     n
# 含     n
# A     eng
# 抗原     n
# 和     c
# H     eng
# 抗原     n
# 的     uj
# 叫做     v
# A型     n
# ，     x
# A型     n
# 的     uj
# 人     n
# 血清     n
# 中     f
# 含有     v
# 抗     nz
# B     eng
# 抗体     n
# ；     x
# 红细胞     n
# 含     n
# B     eng
# 抗原     n
# 和     c
# H     eng
# 抗原     n
# 的     uj
# 叫做     v
# B型     n
# ，     x
# B型     n
# 的     uj
# 人     n
# 血清     n
# 中     f
# 含有     v
# 抗     nz
# A     eng
# 抗体     n
# ；     x
# 红细胞     n
# 含     n
# A     eng
# 抗原     n
# 、     x
# B     x
# 抗原     n
# 和     c
# H     eng
# 抗原     n
# ，     x
# 叫做     v
# AB型     n
# ，     x
# 这种     r
# 血型     n
# 的     uj
# 人     n
# 血清     n
# 中     f
# 没有     v
# 抗     nz
# A     eng
# 抗体     n
# 和     c
# 抗     v
# B     eng
# 抗体     n
# ；     x
# 红细胞     n
# 只有     c
# H     x
# 抗原     n
# ，     x
# 叫做     v
# O型     n
# ，     x
# O型     n
# 的     uj
# 人     n
# 血清     n
# 中     f
# 含有     v
# 抗     nz
# A     eng
# 抗体     n
# 和     c
# 抗     v
# B     eng
# 抗体     n
# ABO     eng
# 血型     n
# 物质     n
# 除     p
# 存在     v
# 于     p
# 红     n
# 细胞膜     n
# 上外     f
# ，     x
# 还     d
# 出现     v
# 于     p
# 唾液     n
# 、     x
# 胃液     n
# 、     x
# 精液     n
# 等     u
# 分泌液     n
# 中     f
# 中国     ns
# 60     m
# ％     x
# 汉族人     nz
# 唾液     n
# 中     f
# 有     v
# ABO     eng
# 血型     n
# 物质     n
# 血型     n
# 物质     n
# 的     uj
# 化学     n
# 本质     n
# 是     v
# 指     n
# 构成     v
# 血型     n
# 抗原     n
# 的     uj
# 糖蛋白     n
# 或     c
# 糖脂     n
# ，     x
# 而     c
# 血型     n
# 的     uj
# 特异性     n
# 主要     b
# 取决于     v
# 血型     n
# 抗原     n
# 糖链     n
# 的     uj
# 组成     v
# （     x
# 即     v
# 血型     n
# 抗原     n
# 的     uj
# 决定簇     i
# 在     p
# 糖链     n
# 上     f
# ）     x
# A     x
# 、     x
# B     x
# 、     x
# H3     eng
# 种     m
# 血型     n
# 抗原     n
# 化学     n
# 结构     n
# 的     uj
# 差异     n
# ，     x
# 仅     d
# 在于     v
# 糖链     n
# 末端     f
# 的     uj
# 1     m
# 个     m
# 单糖     n
# A     x
# 抗原     n
# 糖链     n
# 末端     f
# 为     p
# N     eng
# -     x
# 乙酰     n
# 半乳糖     n
# ，     x
# 而     c
# B     eng
# 抗原     n
# 糖链     n
# 末端     f
# 为     p
# 半乳糖     n
# ，     x
# H     x
# 抗原     n
# 和     c
# A     eng
# 、     x
# B     x
# 抗原     n
# 相比     v
# 则     d
# 糖链     n
# 末端     f
# 少     a
# 1     m
# 个     m
# 半乳糖     n
# 或     c
# N     eng
# -     x
# 乙酰     n
# 半乳糖     n
# 1981     m
# 年     m
# 已有     v
# 人用     n
# 绿     n
# 咖啡豆     n
# 酶     n
# （     x
# 半     m
# 乳     n
# 糖苷酶     n
# ）     x
# 作用     v
# 于     p
# B型     n
# 红细胞     n
# ，     x
# 切去     v
# B     eng
# 抗原     n
# 上     f
# 的     uj
# 半乳糖     n
# ，     x
# 从而     c
# 使     v
# B型     n
# 转变成     l
# O型     n
# 获得成功     l
# E     x
# ．     x
# vo     eng
# 邓格恩     nr
# 及     c
# L     eng
# ．     x
# 希尔     nrt
# 斯费尔德     nrt
# 于     p
# 1911     m
# 年     m
# 发现     v
# A     x
# 血型     n
# 的     uj
# 亚型     n
# 他们     r
# 看到     v
# 不同     a
# A型     n
# 人     n
# 的     uj
# 红细胞     n
# 与     p
# 抗     nz
# A     eng
# 血清     n
# 发生     v
# 凝集反应     n
# 的     uj
# 强度     n
# 不     d
# 一     m
# ，     x
# 在     p
# 反应     vn
# 弱     a
# 的     uj
# A型     n
# 人     n
# 血清     n
# 中     f
# 还有     v
# 一种     m
# 抗体     n
# 能     v
# 与     p
# 反应     vn
# 强     a
# 的     uj
# A型     n
# 红细胞     n
# 发生     v
# 凝集反应     n
# 据此     d
# 认为     v
# 在     p
# A型     n
# 中     f
# 存在     v
# 亚型     n
# ；     x
# 即     c
# A1     eng
# 及     c
# A2     eng
# 亚型     n
# A1     eng
# .     m
# 型     k
# 红细胞     n
# 与     p
# 抗     nz
# A     eng
# 血清     n
# （     x
# 来自     v
# B     eng
# 或     c
# O型     n
# 人     n
# ）     x
# 反应     vn
# 强     a
# ，     x
# 而     c
# A2     eng
# 型     k
# 红细胞     n
# 与     p
# 抗     nz
# A     eng
# 血清     n
# 反应     vn
# 弱     a
# 而且     c
# 在     p
# 部分     n
# A2     eng
# 型     k
# 人     n
# 的     uj
# 血清     n
# 中     f
# ，     x
# 除     p
# 存在     v
# 的     uj
# 抗     vn
# B     eng
# 外     n
# ，     x
# 还有     v
# 不规则     a
# 的     uj
# 抗     vn
# A1     eng
# 在     p
# B型     n
# 人     n
# 血清     n
# 中     f
# 有     v
# 两种     m
# 抗体     n
# ：     x
# 抗     nz
# A     eng
# 及     c
# 抗     v
# A1     eng
# 抗     nz
# A     eng
# 能     v
# 与     p
# A1     eng
# 及     c
# A2     eng
# 细胞     n
# 发生     v
# 反应     vn
# ；     x
# 抗     nz
# A1     eng
# 只     d
# 与     p
# A1     eng
# 细胞     n
# 发生     v
# 反应     vn
# A1     eng
# 型     k
# 红细胞     n
# 上有     v
# A     eng
# 及     c
# A1     eng
# 两种     m
# 抗原     n
# A2     eng
# 细胞     n
# 上     f
# 只有     c
# A     x
# 抗原     n
# AB型     n
# 也     d
# 可     v
# 分为     v
# A1B     eng
# 及     c
# A2B     eng
# 等     u
# 亚型     n
# 此外     c
# 还有     v
# 一些     m
# 其他     r
# 亚型     n
# MN     eng
# 血型     n
# 红     a
# 细胞膜     n
# 上     f
# 另一类     i
# 血型     n
# 抗原     n
# 叫     v
# MN     eng
# 抗原     n
# ，     x
# 即     v
# 红     a
# 细胞膜     n
# 上     f
# 的     uj
# 血型     n
# 糖蛋白     n
# A     x
# 它     r
# 在     p
# SOS     eng
# 凝胶电泳     n
# 谱     v
# 上     f
# 显示     v
# 两条     m
# 区带     n
# ，     x
# 即     c
# PAS     eng
# －     x
# 1     m
# 和     c
# PAS     eng
# －     x
# 2     x
# ，     x
# 血型     n
# 糖蛋白     n
# A     eng
# 是     v
# 两者     n
# 的     uj
# 二聚物     n
# 已知     v
# 血型     n
# 糖蛋白     n
# A     eng
# 由     c
# 131     m
# 个     m
# 氨基酸     nz
# 组成     v
# ，     x
# 其     r
# 一级     m
# 结构     n
# 已     d
# 测定     v
# （     x
# 图     n
# 2     m
# ）     x
# 血型     n
# 糖蛋白     n
# A     eng
# 的     uj
# 肽链     n
# 呈     v
# 三节     m
# 式     k
# 结构     n
# ，     x
# 中间     f
# 第     m
# 73     m
# ～     x
# 92     m
# 号     m
# 氨基酸     nz
# 为     p
# 疏     vn
# 水性     n
# 肽链     n
# ，     x
# 可     v
# 横穿     v
# 膜     n
# 脂层     n
# ；     x
# N     eng
# 端     v
# 肽链     n
# 位于     v
# 膜     n
# 外侧     f
# ，     x
# 与     p
# 血型     n
# 活性     n
# 有关     vn
# ，     x
# 在     p
# 这段     r
# 肽链     n
# 上     f
# 分布     v
# 有     v
# 15     m
# 条     n
# O     eng
# -     x
# 糖苷键     n
# 型     k
# 糖链     n
# 和     c
# 1     m
# 条     n
# N     eng
# -     x
# 糖苷键     n
# 型     k
# 糖链     n
# ，     x
# 糖链     n
# 中     f
# 唾液酸     n
# 占     v
# 红     a
# 细胞膜     n
# 上     f
# 全部     n
# 唾液酸     n
# 的     uj
# 一半     m
# 以上     f
# ；     x
# C     eng
# 端     v
# 肽链     n
# 位于     v
# 膜     n
# 内侧     f
# ，     x
# 含     v
# 较     d
# 多     m
# 酸性     n
# 氨基酸     nz
# MN     eng
# 抗原     n
# 由     c
# M     eng
# 抗原     n
# 和     c
# N     eng
# 抗原     n
# 两     m
# 部分     n
# 组成     v
# ，     x
# 如果     c
# 用     p
# 神经     n
# 氨酸     n
# 酶     n
# 将     d
# M     eng
# 抗原     n
# 切去     v
# 1     m
# 个     m
# 唾液酸     n
# （     x
# N     x
# -     x
# 乙酰     n
# 神经     n
# 氨酸     n
# ）     x
# ，     x
# 则     d
# 为     p
# N     eng
# 抗原     n
# ，     x
# 如     v
# 再     d
# 切去     v
# 一个     m
# 唾液酸     n
# 则     d
# 抗原性     n
# 完全     ad
# 失去     v
# MN     eng
# 抗原     n
# 的     uj
# 抗原性     n
# 还     d
# 和     c
# 肽链     n
# 上     f
# 的     uj
# 氨基     n
# 有关     vn
# ，     x
# 若     c
# 将     d
# 氨基     n
# 用     p
# 乙酰基     nz
# 保护     v
# 后     f
# 即     v
# 失去     v
# 抗原性     n
# 白细胞     n
# 血型     n
# —     x
# —     x
# HLA     eng
# HLA     eng
# 是     v
# 人类     n
# 白细胞     n
# 抗原     n
# 中     f
# 最     d
# 重要     a
# 的     uj
# 一类     m
# 与     p
# 红细胞     n
# 血型     n
# 相比     v
# ，     x
# 人们     n
# 对     p
# 白细胞     n
# 抗原     n
# 的     uj
# 了解     v
# 较晚     d
# ，     x
# 人体     n
# 第一个     m
# 白细胞     n
# 抗原     n
# Mac     eng
# 是     v
# 1958     m
# 年     m
# 法国     ns
# 科学家     n
# J     x
# ．     x
# 多     m
# 塞     v
# 发现     v
# 的     uj
# HLA     eng
# 是     v
# 人体     n
# 白细胞     n
# 抗原     n
# 的     uj
# 英文     nz
# 缩写     v
# ，     x
# 已     d
# 发现     v
# HLA     eng
# 抗原     n
# 有     v
# 144     m
# 种     m
# 以上     f
# ，     x
# 这些     r
# 抗原     n
# 分为     v
# A     x
# 、     x
# B     x
# 、     x
# C     x
# 、     x
# D     x
# 、     x
# DR     eng
# 、     x
# DQ     eng
# 和     c
# DP7     eng
# 个     m
# 系列     q
# ，     x
# 而且     c
# HLA     eng
# 在     p
# 其他     r
# 细胞     n
# 表面     n
# 上     f
# 也     d
# 存在     v
# HLA     eng
# 抗原     n
# 是     v
# 一种     m
# 糖蛋白     n
# （     x
# 含糖     n
# 为     p
# 9     m
# ％     x
# ）     x
# ，     x
# 其     r
# 分子结构     n
# 与     p
# 免疫     v
# 球蛋白     l
# 极     d
# 相似     v
# （     x
# 图     n
# 3     m
# ）     x
# HLA     eng
# 分子     n
# 由     c
# 4     m
# 条     n
# 肽链     n
# 组成     v
# （     x
# 含     n
# 2     m
# 条     n
# 轻链     n
# 和     c
# 2     m
# 条重链     n
# ）     x
# ，     x
# 重链     n
# 上     f
# 连接     v
# 2     m
# 条糖链     n
# HLA     eng
# 分子     n
# 部分     n
# 镶嵌     v
# 在     p
# 细胞膜     n
# 的     uj
# 双脂层     n
# 中     f
# ，     x
# 其     r
# 插入     v
# 膜     n
# 的     uj
# 部分     n
# 相当于     v
# 免疫     v
# 球蛋白     l
# IG     eng
# 的     uj
# Fc     eng
# 区段     n
# ，     x
# 轻链     n
# 为     p
# β     x
# -     x
# 微     n
# 球蛋白     l
# 由于     c
# 分子结构     n
# 上     f
# 的     uj
# 相似     v
# ，     x
# 故     n
# HLA     eng
# 与     p
# 有     v
# 保卫     v
# 功能     n
# 的     uj
# 免疫     v
# 防御     v
# 系统     n
# 密切相关     l
# 此外     c
# ，     x
# HLA     eng
# 和     c
# 红细胞     n
# 血型     n
# 一样     r
# 都     d
# 受     v
# 遗传     vn
# 规律     n
# 的     uj
# 控制     v
# 决定     v
# HL     eng
# A型     n
# 的     uj
# 基因     n
# 在     p
# 第     m
# 6     m
# 对     p
# 染色体     n
# 上     f
# 每个     r
# 人     n
# 分别     d
# 可     v
# 从     p
# 父母     n
# 获得     v
# 一套     m
# 染色体     n
# ，     x
# 所以     c
# 一个     m
# 人     n
# 可以     c
# 同时     c
# 查出     v
# A     x
# 、     x
# B     x
# 、     x
# C     x
# 、     x
# D     eng
# 和     c
# DR5     eng
# 个     m
# 系列     q
# 中     f
# 的     uj
# 5     m
# ～     x
# 10     m
# 种     m
# 白细胞     n
# 型     k
# ，     x
# 因此     c
# 表现     v
# 出来     v
# 的     uj
# 各种     r
# 白细胞     n
# 型     k
# 有     v
# 上     f
# 亿种     m
# 之     u
# 多     m
# 在     p
# 无     v
# 血缘关系     l
# 的     uj
# 人间     n
# 找出     v
# HLA     eng
# 相同     d
# 的     uj
# 两个     m
# 是     v
# 很     d
# 困难     an
# 的     uj
# 但     c
# 同胞兄弟     n
# 姊妹     n
# 之间     f
# 总是     c
# 有     v
# 1     m
# ／     x
# 4     x
# 机会     n
# HLA     eng
# 完全相同     i
# 或     c
# 完全     ad
# 不同     a
# 因此     c
# 法医鉴定     n
# 亲缘     n
# 关系     n
# 时     n
# ，     x
# HLA     eng
# 测定     v
# 是     v
# 最     d
# 有力     n
# 的     uj
# 工具     n
# 动物     n
# 的     uj
# 血型     n
# 过去     t
# 人们     n
# 认为     v
# 只有     c
# 人才     n
# 有     v
# 血型     n
# ，     x
# 现在     t
# 已知     v
# 狗     n
# 、     x
# 鸡     n
# 和     c
# 许多     m
# 动物     n
# 都     d
# 有     v
# 血型     n
# 系统     n
# 生长     n
# 在     p
# 美国     ns
# 缅因     ns
# 海湾     ns
# 的     uj
# 角鲨     n
# 有     v
# 4     m
# 种     m
# 血型     n
# 大马哈鱼     nz
# 至少     d
# 有     v
# 8     m
# 种     m
# 抗原     n
# 类型     n
# 或     c
# 类型     n
# 的     uj
# 组合     v
# 这些     r
# 不同     a
# 类型     n
# 的     uj
# 出现     v
# 通常     d
# 随     v
# 不同     a
# 地区     n
# 的     uj
# 种群     n
# 而     c
# 异     n
# 家畜     n
# 也     d
# 有     v
# 血型     n
# ，     x
# 马有     nr
# 4     m
# 种     m
# ，     x
# 牛     n
# 有     v
# 3     m
# 种     m
# ，     x
# 猪     n
# 也     d
# 有     v
# 4     m
# 种     m
# 灵长类     n
# 的     uj
# 血型     n
# 可以     c
# 通过     p
# 抗     nz
# A     eng
# 和     c
# 抗     v
# B     eng
# 血清     n
# 来     v
# 测定     v
# 黑猩猩     n
# 的     uj
# 血     n
# 全部     n
# 属于     v
# O型     n
# 或     c
# A型     n
# ，     x
# 猩猩     n
# 属于     v
# B型     n
# ，     x
# 大猩猩     n
# 有     v
# B型     n
# 也     d
# 有     v
# A型     n
# ，     x
# 长臂猿     n
# 血型     n
# 有     v
# A型     n
# 、     x
# B型     n
# 及     c
# AB型     n
# 低等     b
# 灵长类     n
# 在     p
# 红血球     n
# 里     f
# 没有     v
# 抗原     n
# ，     x
# 但     c
# 在     p
# 它们     r
# 的     uj
# 唾液     n
# 里     f
# 分泌     v
# ABO     eng
# 抗原     n
# 旧大陆     ns
# 猴     ng
# 大多数     m
# 是     v
# 血型     n
# A型     n
# ，     x
# 新大陆     nz
# 猴     ng
# 血型     n
# 也     d
# 是     v
# A型     n
# ，     x
# 但     c
# 个别     n
# 的     uj
# 在     p
# 唾液     n
# 里     f
# 有     v
# 象     n
# B     eng
# 一样     r
# 的     uj
# 抗原     n
# 在     p
# 某些     r
# 灵长类     n
# 中     f
# 发现     v
# 具有     v
# 类似     v
# 人类     n
# M     eng
# 的     uj
# 抗原     n
# ，     x
# 如     v
# 在     p
# 黑猩猩     n
# 体内     s
# 发现     v
# 了     ul
# 具有     v
# M     x
# 血型     n
# 和     c
# N     eng
# 血型     n
# ，     x
# 在     p
# 灵长类     n
# 中     f
# 也     d
# 发现     v
# 具     v
# Rh     eng
# 抗原     n
# 的     uj
# 来源     n
# :     x
# 高中生物     l
# 资源网     n
# 2     x
# ;     x

# %%
import re
# 逆向最大匹配分词错误分析

RenGong = []
incommen_NiXiang = 0 # 用来记录人工分词和Nixiang分词各个相同元素的个数之差，它们的差就是分词失败多出来的那个部分
NiXiang_ded = list(set(NiXiang)) # 去重，防止记录重复

print('--------------------根据人工分词判断出的逆向最大匹配分词中可能错误的分词↓--------------------')
with open('95-预处理 - 人工分词.txt',encoding='ANSI') as fp:  
    for line in fp:
        line = re.sub(r'[\n]','',line) # 将line中的'\n'去掉
        RenGong.append(line) # 把人工分词的结果用列表保存下来
# 对逆向最大匹配分词做分析，把可能错误的分词找出来，即不在人工分词里面能找到的词
for i in ans_reverse:
    if(RenGong.count(i) == 0):
        print(i)           # 输出可能出错的分词
for j in NiXiang_ded:        # 记录人工分词和HanLP分词各个相同元素的个数之差
    if(RenGong.count(j) !=0):
        incommen_NiXiang = incommen_NiXiang + abs(NiXiang.count(j)-RenGong.count(j))  # 加上两者差的绝对值
print('---------------------------------------')
print('人工分词和逆向最大匹配分词各个相同元素的个数之差:',incommen_NiXiang) # 输出结果，记录下来
# Out:
# --------------------根据人工分词判断出的逆向最大匹配分词中可能错误的分词↓--------------------
#
# 蛋白
# 广义
# 重要
# 广泛
# 施泰纳
# 兰德
# ．
# K
# 年
# 1900
# 别人
# 中有
# 者
# 对应
# 相
# 中有
# 对应
# N
# M
# 种
# 3
# 种新
# 3
# 种
# 3
# 新
# N
# M
# 相距甚远
# 容易
# 中有
# 相应
# 中来
# 球蛋白
# 抗人
# 年
# 1945
# 新
# 因
# 因
# 低
# 蛋白
# 收缩
# 及膜
# 蛋白
# 简单
# 种
# 3
# 夹杂着
# 红
# 内
# 地面
# 液中
# 体
# 便是
# 分离出来
# 或同
# -
# 终
# 胺
# 乙酰
# -
# N
# 终
# 液中
# 体
# 虽
# 醇
# 氨
# 鞘
# 神经
# 合
# 化
# 水
# 碳
# ·
# 行
# 活性
# 等物
# 氢化物
# 经硫
# IP1
# 抗
# IB
# 抗
# 抗
# IH
# 如抗
# 复合
# 是从
# 存
# 虽
# 液中
# 液中
# 第四
# r
# e
# d
# o
# R
# o
# d
# i
# h
# 泳动慢
# 快
# 种
# 3
# r
# e
# d
# o
# R
# o
# d
# i
# h
# r
# e
# d
# o
# R
# o
# d
# i
# h
# 推算出
# 及抗
# 兔抗
# 标记
# 个体发育
# 脆弱
# 细
# 相应
# P1
# 抗
# 厘米
# 10
# 抗
# i
# 抗
# y
# f
# f
# u
# 稍
# Xa
# o
# d
# i
# h
# 球蛋白
# 一定
# 球蛋白
# 球蛋白
# 球蛋白
# 球蛋白
# 球蛋白
# ”
# “
# ”
# 天然
# “
# 抗原刺激
# 查觉
# 所
# ”
# 天然
# “
# 抗原刺激
# 所
# 周围环境
# ”
# 天然
# “
# 另
# 抗原刺激
# 需要
# ”
# “
# ”
# 天然
# “
# 活性
# 无
# 时即
# ℃
# 25
# ”
# 天然
# “
# 相应
# ”
# 天然
# “
# ”
# 天然
# “
# N
# 及抗
# M
# 而抗
# 球蛋白
# ”
# 天然
# “
# 球蛋白
# ”
# 天然
# “
# ”
# 天然
# “
# K
# 及抗
# N
# 抗
# M
# 抗
# Lea
# 抗
# 如有
# 超免疫
# 抗原刺激
# 抗
# 抗
# 过猪
# 抗毒素
# 破伤风
# ”
# 天然
# “
# 及抗
# 抗
# 相应
# 相应
# 球蛋白
# 抗
# 液中
# 胶体
# 大分子
# 如酶
# 需
# 相应
# 欲
# 类别
# 液中
# 种
# 4
# 抗
# 抗
# 抗
# 抗
# 抗
# 抗
# 液中
# 上外
# 红
# 存
# 中有
# ％
# 60
# 个
# 1
# 种
# H3
# 乙酰
# -
# N
# 个
# 1
# 乙酰
# -
# N
# 获得成功
# 作用
# 糖苷酶
# 半乳
# 酶
# 咖啡豆
# 绿
# 人用
# 年
# 1981
# 年
# 1911
# 斯费尔德
# 希尔
# ．
# L
# 邓格恩及
# vo
# ．
# E
# 一
# 抗
# 抗
# 型
# 抗
# 型
# .
# 抗
# 不规则
# 抗
# 型
# 及抗
# 抗
# 中有
# 抗
# 抗
# 型
# 即红
# 红
# －
# PAS
# 1
# －
# PAS
# 谱
# 凝胶电泳
# SOS
# 图
# 一级
# 个
# 131
# 多
# 含较
# 内侧
# 端
# 占红
# 型
# 糖苷键
# -
# N
# 条
# 1
# 型
# 糖苷键
# -
# O
# 条
# 15
# 活性
# 外侧
# 端
# N
# 脂层
# 水性
# 疏
# 号
# 92
# 73
# 第
# 式
# 三节
# N
# 氨酸
# 神经
# 乙酰
# -
# N
# 个
# 1
# M
# 酶
# 氨酸
# 神经
# 两
# N
# M
# —
# —
# 重要
# 最
# 多塞
# ．
# J
# 科学家
# 法国
# 年
# 1958
# 个
# DP7
# 种
# 144
# 缩写
# 英文
# 3
# 图
# 球蛋白
# 分子结构
# ％
# 9
# 含糖
# 条糖链
# 条
# 条
# 条
# 4
# 球蛋白
# 微
# -
# β
# 区段
# Fc
# 球蛋白
# 密切相关
# 防御
# 分子结构
# 规律
# 6
# 第
# HL
# 多
# 亿种
# 型
# 型
# 种
# 10
# 个
# DR5
# 困难
# 人间
# 血缘关系
# 无
# 4
# ／
# 1
# 姊妹
# 同胞兄弟
# 有力
# 最
# 亲缘
# 法医鉴定
# 人才
# 种
# 4
# 海湾
# 缅因
# 种
# 8
# 地区
# 种
# 4
# 种
# 3
# 牛有
# 种
# 4
# 马有
# 抗
# 抗
# 有象
# 猴
# 新大陆
# 猴
# 旧大陆
# N
# M
# M
# ---------------------------------------
# 人工分词和逆向最大匹配分词各个相同元素的个数之差: 551

# %%
import re
# HanLP的错误分析

incommen_HanLP = 0 # 用来记录人工分词和HanLP分词各个相同元素的个数之差，它们的差就是分词失败多出来的那个部分
HanList_ded = list(set(HanList))  # 去重，防止记录重复

print('--------------------根据人工分词判断出的HanLP分词中可能错误的分词↓--------------------')
# 对HanLP分词做分析，把可能错误的分词找出来，即不在人工分词里面能找到的词
for i in HanList:
    if(RenGong.count(i) == 0):
        print(i)   # 输出可能出错的分词
for j in HanList_ded:        # 记录人工分词和HanLP分词各个相同元素的个数之差
    if(RenGong.count(j) !=0):
        incommen_HanLP = incommen_HanLP + abs(HanList.count(j)-RenGong.count(j))  # 加上两者差的绝对值
print(incommen_HanLP) # 输出结果，记录下来
print('---------------------------------------')
print('人工分词和HanLP分词各个相同元素的个数之差:',incommen_HanLP) # 输出结果，记录下来
# Out:
# --------------------根据人工分词判断出的HanLP分词中可能错误的分词↓--------------------
#
# 一
# 种
# 蛋白
# 广义
# 广泛
# 重要
# 1900
# 年
# K
# ．
# 兰德施泰纳
# 别人
# 者
# 一
# 种
# 一
# 种
# 相
# 对应
# 会
# 一
# 种
# 对应
# 3
# 种
# M
# N
# 3
# 种
# 3
# 种
# M
# N
# 两
# 个
# 相距甚远
# 相应
# 容易
# 1945
# 年
# 抗
# 球蛋白
# 新
# 一
# 因其
# 因其
# 低
# 夹杂着
# 3
# 种
# 简单
# 蛋白
# 收缩
# 蛋白
# 地面
# 内
# 分离出来
# 侧
# 链
# 链
# 便是
# 链
# 同一
# 种
# 链
# 链
# 终
# N-
# 乙酰
# 胺
# 链
# 终末
# 端
# D-
# 半
# 乳糖
# 虽
# 中的
# 链
# 链
# 神经
# 鞘
# 氨
# 醇
# ·
# 硫
# 氢化物
# 脲
# 素
# 活性
# 抗
# IH
# 抗
# 抗
# IB
# 抗
# IP
# 1
# 复合
# 两
# 种
# 中的
# 是从
# 中的
# 第
# 四
# 4
# 4
# 3
# 种
# 泳
# 动
# 快
# 泳
# 动
# 慢
# 两
# 种
# 两
# 种
# 全
# 两
# 种
# 标记
# 兔
# 抗
# 抗
# 推算出
# 个体发育
# 相应
# 成人细
# 脆弱
# 10
# 厘米
# 抗
# 1
# 抗
# 远
# 抗
# i
# Xa
# 稍
# 球蛋白
# 抗
# 体
# 五
# 类
# 关的
# 三
# 类
# 查觉
# 抗原刺激
# “
# 天然
# 抗
# 体
# ”
# “
# ”
# 抗原刺激
# “
# 天然
# 抗
# 体
# ”
# 中所
# “
# 天然
# 抗
# 体
# ”
# 两
# 种
# 一
# 种
# “
# ”
# 需要
# 抗原刺激
# 另
# 一
# 种
# “
# 天然
# 抗
# 体
# ”
# 周围环境
# 所
# 第二
# 页
# “
# 天然
# 抗
# 体
# ”
# 相应
# 多
# “
# 天然
# 抗
# 体
# ”
# 25
# ℃
# 无
# 活性
# “
# 天然
# 抗
# 体
# ”
# 抗
# M
# 抗
# N
# “
# 天然
# 抗
# 体
# ”
# “
# 天然
# 抗
# 体
# ”
# 如有
# 抗
# Lea
# 抗
# M
# 抗
# N
# 抗
# K
# “
# 天然
# 抗
# 体
# ”
# 抗原刺激
# 超免疫
# 破伤风
# 抗毒素
# 中的
# 抗
# 抗
# 抗
# 抗
# “
# 天然
# 抗
# 体
# ”
# 相应
# 相应
# 欲
# 相应
# 需
# 酶
# 大分子
# 胶
# 抗
# 球蛋白
# 多
# 类
# 别的
# O
# 型
# 4
# 种
# 型
# 型
# 抗
# 型
# 型
# 抗
# 型
# 抗
# 抗
# O
# 型
# O
# 型
# 抗
# 抗
# 上外
# 60
# ％
# 链
# 链
# 3
# 种
# 链
# 1
# 个
# 链
# N-
# 乙酰
# 半
# 乳糖
# 链
# 半
# 乳糖
# 链
# 1
# 个
# N-
# 乙酰
# 1981
# 年
# 有人
# 绿
# 咖啡豆
# 酶
# 苷
# 酶
# 型
# 半
# 乳糖
# 型
# O
# 型
# 获得成功
# E
# ．
# vo
# 邓
# 格
# 恩
# L
# ．
# 希尔斯
# 费尔德
# 1911
# 年
# 型
# 抗
# 型
# 一
# 种
# 型
# 型
# 1
# 1
# .
# 型
# 抗
# O
# 型
# 型
# 抗
# 型
# 抗
# 不规则
# 抗
# 1
# 型
# 两
# 种
# 抗
# 抗
# 1
# 抗
# 1
# 抗
# 1
# 1
# 1
# 型
# 1
# 两
# 种
# 型
# 1
# 另
# SOS
# 凝胶电泳
# 谱
# 两
# 条
# PAS
# －
# 1
# PAS
# －
# 二
# 聚
# 131
# 个
# 氨基酸组成
# 一级
# 图
# 三节
# 式
# 第
# 73
# 92
# 号
# 疏水
# 性
# 脂
# 层
# N
# 端肽
# 链
# 外侧
# 活性
# 15
# 条
# O-
# 糖苷键
# 型
# 链
# 1
# 条
# N-
# 糖苷键
# 型
# 链
# 链
# 端肽
# 链
# 内侧
# M
# N
# 两
# 神经
# 氨酸
# 酶
# M
# 1
# 个
# N-
# 乙酰
# 神经氨酸
# N
# 最重要
# 第
# 1958
# 年
# 法国
# 科学家
# J
# ．
# 多
# 塞
# 英文
# 缩写
# 144
# 种
# 7
# 个
# 一
# 种
# 含糖
# 9
# ％
# 分子结构
# 图
# 3
# 4
# 条
# 条
# 条
# 重
# 链
# 重
# 链
# 条
# 链
# 双
# 脂
# 层
# Fc
# 区段
# β
# -
# 微
# 球蛋白
# 分子结构
# 防御
# 密切相关
# 规律
# 型
# 第
# 6
# 一
# 套
# 个
# 中的
# 10
# 种
# 型
# 型
# 亿
# 种
# 多
# 无
# 血缘关系
# 人间
# 两
# 个
# 困难
# 同胞兄弟
# 姊妹
# 1
# ／
# 4
# 法医鉴定
# 最
# 有力
# 人才
# 缅因
# 海湾
# 4
# 种
# 8
# 种
# 地区
# 异
# 马有
# 4
# 种
# 牛有
# 3
# 种
# 4
# 种
# 抗
# 抗
# O
# 型
# 型
# 型
# 型
# 型
# 型
# 型
# 型
# 旧
# 大陆
# 猴
# 型
# 新
# 大陆
# 猴
# 型
# 象
# 一
# 样
# M
# M
# N
# 552
# ---------------------------------------
# 人工分词和HanLP分词各个相同元素的个数之差: 552

# %%
import re
# jieba的错误分析
incommen_jieba = 0 # 用来记录人工分词和jieba分词各个相同元素的个数之差，它们的差就是分词失败多出来的那个部分
jiebaList_ded = list(set(jiebaList))  # 去重，防止记录重复
print('--------------------根据人工分词判断出的jieba分词中可能错误的分词↓--------------------')
# 对jieba分词做分析，把可能错误的分词找出来，即不在人工分词里面能找到的词
for i in jiebaList:
    if(RenGong.count(i) == 0):
        print(i)  # 输出可能出错的分词
for j in jiebaList_ded:        # 记录人工分词和jieba分词各个相同元素的个数之差
    if(RenGong.count(j) !=0):
        incommen_jieba = incommen_jieba + abs(jiebaList.count(j)-RenGong.count(j))  # 加上两者差的绝对值
print('---------------------------------------')
print('人工分词和Hjieba分词各个相同元素的个数之差:',incommen_jieba) # 输出结果，记录下来
# Out:
# --------------------根据人工分词判断出的jieba分词中可能错误的分词↓--------------------
#
# 蛋白
# 广义
# 广泛
# 重要
# 1900
# 年
# K
# ．
# 兰德
# 施泰纳
# 别人
# 者
# 相对
# 上有
# 会
# 对应
# 3
# 种
# M
# N
# 3
# 种
# 3
# 种
# 新
# 新
# M
# N
# 相距甚远
# 相应
# 容易
# 1945
# 年
# 抗人
# 球蛋白
# 中来
# 新
# 一
# 或因其
# 太
# 高
# 或因其
# 太
# 低
# 低
# 红
# 夹杂着
# 3
# 种
# 简单
# 蛋白
# 收缩
# 蛋白
# 地面
# 内
# 分离出来
# 便是
# 或同
# 终
# N
# -
# 乙酰
# 胺
# 终
# -
# 虽
# 神经
# 鞘氨醇
# ·
# 经硫
# 氢化物
# 等物
# 活性
# 行
# 抗
# IH
# 抗
# 抗
# IB
# 抗
# IP1
# 复合
# 是从
# 第四
# 3
# 种
# 快
# 慢
# 上有
# 上有
# 标记
# 兔抗
# 抗
# 推算出
# 个体发育
# 相应
# 细
# 脆弱
# 10
# 厘米
# 抗
# P1
# 抗
# 抗
# i
# Xa
# 球蛋白
# 一定
# 球蛋白
# 球蛋白
# 球蛋白
# 球蛋白
# 球蛋白
# 查觉
# 抗原刺激
# “
# 天然
# ”
# “
# ”
# 抗原刺激
# “
# 天然
# ”
# 所
# “
# 天然
# ”
# “
# ”
# 需要
# 抗原刺激
# 另
# “
# 天然
# ”
# 周围环境
# 所
# “
# 天然
# ”
# 相应
# “
# 天然
# ”
# 25
# ℃
# 无
# 活性
# “
# 天然
# ”
# 抗
# M
# 抗
# N
# “
# 天然
# ”
# 球蛋白
# “
# 天然
# ”
# 球蛋白
# 如有
# 抗
# Lea
# 抗
# M
# 抗
# N
# 抗
# K
# “
# 天然
# ”
# 抗原刺激
# 超免疫
# 破伤风
# 抗毒素
# 抗
# 抗
# 抗
# 抗
# “
# 天然
# ”
# 相应
# 相应
# 欲
# 相应
# 需
# 酶
# 大分子
# 胶体
# 液
# 抗
# 球蛋白
# 多
# 类别
# 4
# 种
# 抗
# 抗
# 抗
# 抗
# 抗
# 抗
# 红
# 上外
# 60
# ％
# H3
# 种
# 1
# 个
# N
# -
# 乙酰
# 1
# 个
# N
# -
# 乙酰
# 1981
# 年
# 人用
# 绿
# 咖啡豆
# 酶
# 半
# 乳
# 糖苷酶
# 作用
# 获得成功
# E
# ．
# vo
# 邓格恩
# L
# ．
# 希尔
# 斯费尔德
# 1911
# 年
# 抗
# 一
# .
# 型
# 抗
# 型
# 抗
# 型
# 抗
# 不规则
# 抗
# 抗
# 抗
# 抗
# 抗
# 型
# 上有
# 红
# 红
# SOS
# 凝胶电泳
# 谱
# PAS
# －
# 1
# PAS
# －
# 131
# 个
# 一级
# 图
# 三节
# 式
# 第
# 73
# 92
# 号
# 疏
# 水性
# 脂层
# N
# 端
# 外侧
# 活性
# 15
# 条
# O
# -
# 糖苷键
# 型
# 1
# 条
# N
# -
# 糖苷键
# 型
# 红
# 端
# 内侧
# 多
# M
# N
# 两
# 神经
# 氨酸
# 酶
# M
# 1
# 个
# N
# -
# 乙酰
# 神经
# 氨酸
# N
# —
# —
# 最
# 重要
# 1958
# 年
# 法国
# 科学家
# J
# ．
# 多
# 塞
# 英文
# 缩写
# 144
# 种
# DP7
# 个
# 含糖
# 9
# ％
# 分子结构
# 球蛋白
# 图
# 3
# 4
# 条
# 条
# 条重链
# 条糖链
# 球蛋白
# Fc
# 区段
# β
# -
# 微
# 球蛋白
# 分子结构
# 防御
# 密切相关
# 规律
# HL
# 第
# 6
# DR5
# 个
# 10
# 种
# 型
# 型
# 亿种
# 多
# 无
# 血缘关系
# 人间
# 困难
# 同胞兄弟
# 姊妹
# 1
# ／
# 4
# 法医鉴定
# 亲缘
# 最
# 有力
# 人才
# 缅因
# 海湾
# 4
# 种
# 8
# 种
# 地区
# 异
# 马有
# 4
# 种
# 3
# 种
# 4
# 种
# 抗
# 抗
# 旧大陆
# 猴
# 新大陆
# 猴
# 象
# M
# M
# N
# ---------------------------------------
# 人工分词和Hjieba分词各个相同元素的个数之差: 541
